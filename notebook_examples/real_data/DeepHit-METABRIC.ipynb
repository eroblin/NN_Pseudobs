# %%
import os
main = os.chdir(os.path.dirname(os.path.dirname(os.getcwd())))

# %%
import json
import numpy as np
import pandas as pd

from model import model_architecture, output_results, utils
from pycox.models import DeepHitSingle
from sksurv.util import Surv as skSurv
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # I. METABRIC data

# %% [markdown]
# We use METABRIC data. We use clinical and pathological informations and gene expression data. Missing values for explanatory variables are completed. Data is first splitted into 5 folds for the double 5 folds cross validation.  The same 5 folds are used for all the models and are stored in the file "folds.json".

# %%
name = "DeepHit"

# %%
df = pd.read_csv("data/real_data/metabric_imputed.csv")

# %%
with open('data/real_data/folds.json') as f:
        kfolds = json.load(f)

# %% [markdown]
# # II. Model's construction and training

# %% [markdown]
# The parameters of the architecture are the one listed in the parameters dataframe, selected by a double 5-fold cross-validation among 400 sets of parameters. There are 5 sets of parameters, corresponding to each fold of the outerloop.

# %%
results_all = pd.DataFrame(columns=['unoc5', 'unoc10','ibs'])

k=0
for kname, val in kfolds.items():
    param = pd.read_csv('model/best_param_metabric/'+name+'_best_param.csv', sep = ";",index_col=0)
    train_index = val['train']
    val_index = val['test']
    
    df_train, df_val = df.iloc[train_index], df.iloc[val_index]
    
    list_all_cols = df.drop(columns = ['yy','status'],axis=1).columns.to_list()
    cols_leave = ['N', 'grade1','grade2', 'hormonotherapy', 'chemotherapy']
    cols_standardize = [col for col in list_all_cols if col not in cols_leave] 
    standardize = [([col], StandardScaler()) for col in cols_standardize]
    leave = [(col, None) for col in cols_leave]
    df_mapper = DataFrameMapper(standardize + leave, df_out = True)
    
    X_train = df_train.drop(["yy","status"], axis = 1)
    X_train = df_mapper.fit_transform(X_train).astype('float32')
    X_val = df_val.drop(["yy","status"], axis = 1)
    X_val = df_mapper.transform(X_val).astype('float32')

    if name=="DeepHit":
        num_durations = 10 
        labtrans = DeepHitSingle.label_transform(num_durations)
        y_train = labtrans.fit_transform(*(df_train['yy'].values, df_train['status'].values))
    elif name=="CoxTime":
        labtrans = CoxTime.label_transform()
        y_train = labtrans.fit_transform(*(df_train['yy'].values, df_train['status'].values))
    else:
        labtrans=""
        y_train = (df_train['yy'].values, df_train['status'].values)

    model,callbacks  = model_architecture.build_model(np.array(X_train), 
                               param['neurons'][kname], 
                               param['dropout'][kname], 
                               param['activation'][kname],
                               param['lr'][kname],
                               param['optimizer'][kname],
                               param['n_layers'][kname],
                               name,
                               labtrans)
    log = model.fit(np.array(X_train), 
                     y_train,
                    int(param['batch_size'][kname]),
                     epochs=100, 
                     callbacks = callbacks, 
                     verbose = True)
    surv = model.predict_surv_df(np.array(X_val))
    res = output_results.output_stats(model,surv,X_train, df_train, X_val, df_val)
    results_all = results_all.append(res, ignore_index  = True, sort = False)
    k+=1
# Out:
# 0:	[0s / 0s],		train_loss: 0.6875
# 1:	[0s / 0s],		train_loss: 0.5881
# 2:	[0s / 0s],		train_loss: 0.5250
# 3:	[0s / 0s],		train_loss: 0.5111
# 4:	[0s / 0s],		train_loss: 0.5055
# 5:	[0s / 0s],		train_loss: 0.4888
# 6:	[0s / 0s],		train_loss: 0.4917
# 7:	[0s / 0s],		train_loss: 0.4939
# 8:	[0s / 1s],		train_loss: 0.4835
# 9:	[0s / 1s],		train_loss: 0.4870
# 10:	[0s / 1s],		train_loss: 0.4812
# 11:	[0s / 1s],		train_loss: 0.4776
# 12:	[0s / 1s],		train_loss: 0.4794
# 13:	[0s / 1s],		train_loss: 0.4790
# 14:	[0s / 1s],		train_loss: 0.4739
# 15:	[0s / 1s],		train_loss: 0.4823
# 16:	[0s / 2s],		train_loss: 0.4732
# 17:	[0s / 2s],		train_loss: 0.4720
# 18:	[0s / 2s],		train_loss: 0.4702
# 19:	[0s / 2s],		train_loss: 0.4627
# 20:	[0s / 2s],		train_loss: 0.4650
# 21:	[0s / 2s],		train_loss: 0.4660
# 22:	[0s / 2s],		train_loss: 0.4538
# 23:	[0s / 2s],		train_loss: 0.4582
# 24:	[0s / 3s],		train_loss: 0.4614
# 25:	[0s / 3s],		train_loss: 0.4588
# 26:	[0s / 3s],		train_loss: 0.4590
# 27:	[0s / 3s],		train_loss: 0.4488
# 28:	[0s / 3s],		train_loss: 0.4443
# 29:	[0s / 3s],		train_loss: 0.4421
# 30:	[0s / 3s],		train_loss: 0.4383
# 31:	[0s / 3s],		train_loss: 0.4283
# 32:	[0s / 4s],		train_loss: 0.4333
# 33:	[0s / 4s],		train_loss: 0.4350
# 34:	[0s / 4s],		train_loss: 0.4305
# 35:	[0s / 4s],		train_loss: 0.4337
# 36:	[0s / 4s],		train_loss: 0.4242
# 37:	[0s / 4s],		train_loss: 0.4210
# 38:	[0s / 4s],		train_loss: 0.4261
# 39:	[0s / 5s],		train_loss: 0.4232
# 40:	[0s / 5s],		train_loss: 0.4232
# 41:	[0s / 5s],		train_loss: 0.4252
# 42:	[0s / 5s],		train_loss: 0.4222
# 43:	[0s / 5s],		train_loss: 0.4200
# 44:	[0s / 5s],		train_loss: 0.4042
# 45:	[0s / 5s],		train_loss: 0.4085
# 46:	[0s / 6s],		train_loss: 0.4020
# 47:	[0s / 6s],		train_loss: 0.4061
# 48:	[0s / 6s],		train_loss: 0.3872
# 49:	[0s / 6s],		train_loss: 0.4029
# 50:	[0s / 6s],		train_loss: 0.3971
# 51:	[0s / 6s],		train_loss: 0.3831
# 52:	[0s / 6s],		train_loss: 0.3774
# 53:	[0s / 7s],		train_loss: 0.3735
# 54:	[0s / 7s],		train_loss: 0.3755
# 55:	[0s / 7s],		train_loss: 0.3810
# 56:	[0s / 7s],		train_loss: 0.3936
# 57:	[0s / 7s],		train_loss: 0.3826
# 58:	[0s / 7s],		train_loss: 0.3817
# 59:	[0s / 8s],		train_loss: 0.3688
# 60:	[0s / 8s],		train_loss: 0.3798
# 61:	[0s / 8s],		train_loss: 0.3686
# 62:	[0s / 8s],		train_loss: 0.3713
# 63:	[0s / 8s],		train_loss: 0.3544
# 64:	[0s / 8s],		train_loss: 0.3594
# 65:	[0s / 8s],		train_loss: 0.3681
# 66:	[0s / 8s],		train_loss: 0.3567
# 67:	[0s / 9s],		train_loss: 0.3461
# 68:	[0s / 9s],		train_loss: 0.3454
# 69:	[0s / 9s],		train_loss: 0.3435
# 70:	[0s / 9s],		train_loss: 0.3380
# 71:	[0s / 9s],		train_loss: 0.3542
# 72:	[0s / 9s],		train_loss: 0.3753
# 73:	[0s / 9s],		train_loss: 0.3537
# 74:	[0s / 10s],		train_loss: 0.3456
# 75:	[0s / 10s],		train_loss: 0.3485
# 76:	[0s / 10s],		train_loss: 0.3458
# 77:	[0s / 10s],		train_loss: 0.3225
# 78:	[0s / 10s],		train_loss: 0.3165
# 79:	[0s / 10s],		train_loss: 0.3241
# 80:	[0s / 10s],		train_loss: 0.3352
# 81:	[0s / 10s],		train_loss: 0.3249
# 82:	[0s / 11s],		train_loss: 0.3146
# 83:	[0s / 11s],		train_loss: 0.3150
# 84:	[0s / 11s],		train_loss: 0.3287
# 85:	[0s / 11s],		train_loss: 0.3260
# 86:	[0s / 11s],		train_loss: 0.3286
# 87:	[0s / 11s],		train_loss: 0.3152
# 88:	[0s / 11s],		train_loss: 0.3348
# 89:	[0s / 11s],		train_loss: 0.3583
# 90:	[0s / 12s],		train_loss: 0.3401
# 91:	[0s / 12s],		train_loss: 0.3436
# 92:	[0s / 12s],		train_loss: 0.3553
# 93:	[0s / 12s],		train_loss: 0.3388
# 94:	[0s / 12s],		train_loss: 0.3325
# 95:	[0s / 12s],		train_loss: 0.3209
# 96:	[0s / 12s],		train_loss: 0.3301
# 97:	[0s / 13s],		train_loss: 0.3252
# 98:	[0s / 13s],		train_loss: 0.3223
# 99:	[0s / 13s],		train_loss: 0.3084
# 0:	[0s / 0s],		train_loss: 1.1503
# 1:	[0s / 0s],		train_loss: 1.3503
# 2:	[0s / 0s],		train_loss: 1.0092
# 3:	[0s / 0s],		train_loss: 0.7365
# 4:	[0s / 0s],		train_loss: 0.6200
# 5:	[0s / 0s],		train_loss: 0.5508
# 6:	[0s / 1s],		train_loss: 0.5326
# 7:	[0s / 1s],		train_loss: 0.5093
# 8:	[0s / 1s],		train_loss: 0.4875
# 9:	[0s / 1s],		train_loss: 0.4654
# 10:	[0s / 1s],		train_loss: 0.4712
# 11:	[0s / 2s],		train_loss: 0.4693
# 12:	[0s / 2s],		train_loss: 0.4425
# 13:	[0s / 2s],		train_loss: 0.4430
# 14:	[0s / 2s],		train_loss: 0.4344
# 15:	[0s / 2s],		train_loss: 0.4304
# 16:	[0s / 2s],		train_loss: 0.4303
# 17:	[0s / 3s],		train_loss: 0.4224
# 18:	[0s / 3s],		train_loss: 0.4169
# 19:	[0s / 3s],		train_loss: 0.4140
# 20:	[0s / 3s],		train_loss: 0.4070
# 21:	[0s / 3s],		train_loss: 0.4005
# 22:	[0s / 3s],		train_loss: 0.3980
# 23:	[0s / 4s],		train_loss: 0.3963
# 24:	[0s / 4s],		train_loss: 0.3878
# 25:	[0s / 4s],		train_loss: 0.3867
# 26:	[0s / 4s],		train_loss: 0.3730
# 27:	[0s / 4s],		train_loss: 0.3765
# 28:	[0s / 5s],		train_loss: 0.3600
# 29:	[0s / 5s],		train_loss: 0.3575
# 30:	[0s / 5s],		train_loss: 0.3491
# 31:	[0s / 5s],		train_loss: 0.3426
# 32:	[0s / 5s],		train_loss: 0.3523
# 33:	[0s / 5s],		train_loss: 0.3393
# 34:	[0s / 6s],		train_loss: 0.3425
# 35:	[0s / 6s],		train_loss: 0.3203
# 36:	[0s / 6s],		train_loss: 0.3158
# 37:	[0s / 6s],		train_loss: 0.3278
# 38:	[0s / 6s],		train_loss: 0.3252
# 39:	[0s / 7s],		train_loss: 0.3132
# 40:	[0s / 7s],		train_loss: 0.3032
# 41:	[0s / 7s],		train_loss: 0.3046
# 42:	[0s / 7s],		train_loss: 0.2913
# 43:	[0s / 7s],		train_loss: 0.2954
# 44:	[0s / 8s],		train_loss: 0.2934
# 45:	[0s / 8s],		train_loss: 0.2944
# 46:	[0s / 8s],		train_loss: 0.2929
# 47:	[0s / 8s],		train_loss: 0.2749
# 48:	[0s / 8s],		train_loss: 0.2694
# 49:	[0s / 8s],		train_loss: 0.2621
# 50:	[0s / 9s],		train_loss: 0.2601
# 51:	[0s / 9s],		train_loss: 0.2493
# 52:	[0s / 9s],		train_loss: 0.2590
# 53:	[0s / 9s],		train_loss: 0.2551
# 54:	[0s / 9s],		train_loss: 0.2713
# 55:	[0s / 10s],		train_loss: 0.2690
# 56:	[0s / 10s],		train_loss: 0.2680
# 57:	[0s / 10s],		train_loss: 0.2429
# 58:	[0s / 10s],		train_loss: 0.2331
# 59:	[0s / 10s],		train_loss: 0.2251
# 60:	[0s / 10s],		train_loss: 0.2170
# 61:	[0s / 11s],		train_loss: 0.2163
# 62:	[0s / 11s],		train_loss: 0.2364
# 63:	[0s / 11s],		train_loss: 0.2242
# 64:	[0s / 11s],		train_loss: 0.2097
# 65:	[0s / 11s],		train_loss: 0.2276
# 66:	[0s / 12s],		train_loss: 0.2241
# 67:	[0s / 12s],		train_loss: 0.2252
# 68:	[0s / 12s],		train_loss: 0.2229
# 69:	[0s / 12s],		train_loss: 0.2221
# 70:	[0s / 12s],		train_loss: 0.2298
# 71:	[0s / 12s],		train_loss: 0.2421
# 72:	[0s / 13s],		train_loss: 0.2310
# 73:	[0s / 13s],		train_loss: 0.2010
# 74:	[0s / 13s],		train_loss: 0.1905
# 75:	[0s / 13s],		train_loss: 0.1853
# 76:	[0s / 13s],		train_loss: 0.2133
# 77:	[0s / 13s],		train_loss: 0.2258
# 78:	[0s / 14s],		train_loss: 0.2522
# 79:	[0s / 14s],		train_loss: 0.2817
# 80:	[0s / 14s],		train_loss: 0.2701
# 81:	[0s / 14s],		train_loss: 0.2502
# 82:	[0s / 14s],		train_loss: 0.2278
# 83:	[0s / 14s],		train_loss: 0.2231
# 84:	[0s / 15s],		train_loss: 0.2084
# 85:	[0s / 15s],		train_loss: 0.1860
# 86:	[0s / 15s],		train_loss: 0.1833
# 87:	[0s / 15s],		train_loss: 0.1821
# 88:	[0s / 15s],		train_loss: 0.1797
# 89:	[0s / 15s],		train_loss: 0.1742
# 90:	[0s / 16s],		train_loss: 0.1954
# 91:	[0s / 16s],		train_loss: 0.2028
# 92:	[0s / 16s],		train_loss: 0.1949
# 93:	[0s / 16s],		train_loss: 0.1896
# 94:	[0s / 16s],		train_loss: 0.1998
# 95:	[0s / 16s],		train_loss: 0.2097
# 96:	[0s / 16s],		train_loss: 0.2040
# 97:	[0s / 17s],		train_loss: 0.1749
# 98:	[0s / 17s],		train_loss: 0.1749
# 99:	[0s / 17s],		train_loss: 0.1718
# 0:	[0s / 0s],		train_loss: 8.4994
# 1:	[0s / 0s],		train_loss: 1.7026
# 2:	[0s / 0s],		train_loss: 0.8804
# 3:	[0s / 0s],		train_loss: 0.8620
# 4:	[0s / 0s],		train_loss: 0.8809
# 5:	[0s / 0s],		train_loss: 0.8029
# 6:	[0s / 0s],		train_loss: 0.7158
# 7:	[0s / 0s],		train_loss: 0.7384
# 8:	[0s / 0s],		train_loss: 0.6406
# 9:	[0s / 1s],		train_loss: 0.6161
# 10:	[0s / 1s],		train_loss: 0.5940
# 11:	[0s / 1s],		train_loss: 0.5648
# 12:	[0s / 1s],		train_loss: 0.6070
# 13:	[0s / 1s],		train_loss: 0.5352
# 14:	[0s / 1s],		train_loss: 0.5506
# 15:	[0s / 1s],		train_loss: 0.5164
# 16:	[0s / 1s],		train_loss: 0.4816
# 17:	[0s / 1s],		train_loss: 0.4835
# 18:	[0s / 2s],		train_loss: 0.4997
# 19:	[0s / 2s],		train_loss: 0.4949
# 20:	[0s / 2s],		train_loss: 0.4951
# 21:	[0s / 2s],		train_loss: 0.4964
# 22:	[0s / 2s],		train_loss: 0.4623
# 23:	[0s / 2s],		train_loss: 0.4556
# 24:	[0s / 2s],		train_loss: 0.4787
# 25:	[0s / 2s],		train_loss: 0.4706
# 26:	[0s / 2s],		train_loss: 0.4516
# 27:	[0s / 3s],		train_loss: 0.4502
# 28:	[0s / 3s],		train_loss: 0.4361
# 29:	[0s / 3s],		train_loss: 0.4271
# 30:	[0s / 3s],		train_loss: 0.4244
# 31:	[0s / 3s],		train_loss: 0.4285
# 32:	[0s / 3s],		train_loss: 0.4266
# 33:	[0s / 3s],		train_loss: 0.4428
# 34:	[0s / 3s],		train_loss: 0.4333
# 35:	[0s / 3s],		train_loss: 0.4278
# 36:	[0s / 4s],		train_loss: 0.4307
# 37:	[0s / 4s],		train_loss: 0.4216
# 38:	[0s / 4s],		train_loss: 0.4210
# 39:	[0s / 4s],		train_loss: 0.4370
# 40:	[0s / 4s],		train_loss: 0.4494
# 41:	[0s / 4s],		train_loss: 0.4505
# 42:	[0s / 4s],		train_loss: 0.4731
# 43:	[0s / 4s],		train_loss: 0.4531
# 44:	[0s / 5s],		train_loss: 0.4813
# 45:	[0s / 5s],		train_loss: 0.4548
# 46:	[0s / 5s],		train_loss: 0.4388
# 47:	[0s / 5s],		train_loss: 0.4374
# 48:	[0s / 5s],		train_loss: 0.4352
# 49:	[0s / 5s],		train_loss: 0.4091
# 50:	[0s / 5s],		train_loss: 0.4200
# 51:	[0s / 5s],		train_loss: 0.4041
# 52:	[0s / 5s],		train_loss: 0.4134
# 53:	[0s / 6s],		train_loss: 0.4482
# 54:	[0s / 6s],		train_loss: 0.4104
# 55:	[0s / 6s],		train_loss: 0.4087
# 56:	[0s / 6s],		train_loss: 0.3963
# 57:	[0s / 6s],		train_loss: 0.3863
# 58:	[0s / 6s],		train_loss: 0.4107
# 59:	[0s / 6s],		train_loss: 0.3883
# 60:	[0s / 6s],		train_loss: 0.3949
# 61:	[0s / 6s],		train_loss: 0.4074
# 62:	[0s / 7s],		train_loss: 0.3992
# 63:	[0s / 7s],		train_loss: 0.4003
# 64:	[0s / 7s],		train_loss: 0.3984
# 65:	[0s / 7s],		train_loss: 0.3841
# 66:	[0s / 7s],		train_loss: 0.3692
# 67:	[0s / 7s],		train_loss: 0.3722
# 68:	[0s / 7s],		train_loss: 0.3717
# 69:	[0s / 7s],		train_loss: 0.3684
# 70:	[0s / 8s],		train_loss: 0.3590
# 71:	[0s / 8s],		train_loss: 0.3547
# 72:	[0s / 8s],		train_loss: 0.3488
# 73:	[0s / 8s],		train_loss: 0.3748
# 74:	[0s / 8s],		train_loss: 0.3751
# 75:	[0s / 8s],		train_loss: 0.3548
# 76:	[0s / 8s],		train_loss: 0.4171
# 77:	[0s / 8s],		train_loss: 0.3543
# 78:	[0s / 9s],		train_loss: 0.3781
# 79:	[0s / 9s],		train_loss: 0.3646
# 80:	[0s / 9s],		train_loss: 0.3748
# 81:	[0s / 9s],		train_loss: 0.3414
# 82:	[0s / 9s],		train_loss: 0.3341
# 83:	[0s / 9s],		train_loss: 0.3513
# 84:	[0s / 9s],		train_loss: 0.3500
# 85:	[0s / 10s],		train_loss: 0.3325
# 86:	[0s / 10s],		train_loss: 0.3529
# 87:	[0s / 10s],		train_loss: 0.3381
# 88:	[0s / 10s],		train_loss: 0.3226
# 89:	[0s / 10s],		train_loss: 0.3233
# 90:	[0s / 10s],		train_loss: 0.3190
# 91:	[0s / 10s],		train_loss: 0.3496
# 92:	[0s / 11s],		train_loss: 0.3135
# 93:	[0s / 11s],		train_loss: 0.3284
# 94:	[0s / 11s],		train_loss: 0.3266
# 95:	[0s / 11s],		train_loss: 0.3439
# 96:	[0s / 11s],		train_loss: 0.3249
# 97:	[0s / 11s],		train_loss: 0.3211
# 98:	[0s / 12s],		train_loss: 0.3226
# 99:	[0s / 12s],		train_loss: 0.3097
# 0:	[0s / 0s],		train_loss: 3.1024
# 1:	[0s / 0s],		train_loss: 0.9915
# 2:	[0s / 0s],		train_loss: 0.7515
# 3:	[0s / 0s],		train_loss: 0.5960
# 4:	[0s / 0s],		train_loss: 0.5931
# 5:	[0s / 0s],		train_loss: 0.5583
# 6:	[0s / 0s],		train_loss: 0.5344
# 7:	[0s / 0s],		train_loss: 0.5092
# 8:	[0s / 0s],		train_loss: 0.5256
# 9:	[0s / 0s],		train_loss: 0.4834
# 10:	[0s / 0s],		train_loss: 0.4474
# 11:	[0s / 0s],		train_loss: 0.4740
# 12:	[0s / 0s],		train_loss: 0.4340
# 13:	[0s / 1s],		train_loss: 0.4339
# 14:	[0s / 1s],		train_loss: 0.4335
# 15:	[0s / 1s],		train_loss: 0.4310
# 16:	[0s / 1s],		train_loss: 0.4359
# 17:	[0s / 1s],		train_loss: 0.4239
# 18:	[0s / 1s],		train_loss: 0.4138
# 19:	[0s / 1s],		train_loss: 0.4282
# 20:	[0s / 1s],		train_loss: 0.3992
# 21:	[0s / 1s],		train_loss: 0.4112
# 22:	[0s / 1s],		train_loss: 0.4096
# 23:	[0s / 1s],		train_loss: 0.4019
# 24:	[0s / 1s],		train_loss: 0.4050
# 25:	[0s / 1s],		train_loss: 0.4008
# 26:	[0s / 2s],		train_loss: 0.4053
# 27:	[0s / 2s],		train_loss: 0.3979
# 28:	[0s / 2s],		train_loss: 0.3985
# 29:	[0s / 2s],		train_loss: 0.4110
# 30:	[0s / 2s],		train_loss: 0.3796
# 31:	[0s / 2s],		train_loss: 0.3958
# 32:	[0s / 2s],		train_loss: 0.4068
# 33:	[0s / 2s],		train_loss: 0.3874
# 34:	[0s / 2s],		train_loss: 0.3999
# 35:	[0s / 2s],		train_loss: 0.4068
# 36:	[0s / 2s],		train_loss: 0.3835
# 37:	[0s / 2s],		train_loss: 0.3794
# 38:	[0s / 3s],		train_loss: 0.4002
# 39:	[0s / 3s],		train_loss: 0.3735
# 40:	[0s / 3s],		train_loss: 0.3834
# 41:	[0s / 3s],		train_loss: 0.3872
# 42:	[0s / 3s],		train_loss: 0.3936
# 43:	[0s / 3s],		train_loss: 0.3935
# 44:	[0s / 3s],		train_loss: 0.3798
# 45:	[0s / 3s],		train_loss: 0.3976
# 46:	[0s / 3s],		train_loss: 0.3920
# 47:	[0s / 3s],		train_loss: 0.3810
# 48:	[0s / 3s],		train_loss: 0.3976
# 49:	[0s / 3s],		train_loss: 0.4139
# 50:	[0s / 3s],		train_loss: 0.3922
# 51:	[0s / 4s],		train_loss: 0.3878
# 52:	[0s / 4s],		train_loss: 0.3884
# 53:	[0s / 4s],		train_loss: 0.3787
# 54:	[0s / 4s],		train_loss: 0.3944
# 55:	[0s / 4s],		train_loss: 0.3747
# 56:	[0s / 4s],		train_loss: 0.3813
# 57:	[0s / 4s],		train_loss: 0.3873
# 58:	[0s / 4s],		train_loss: 0.3787
# 59:	[0s / 4s],		train_loss: 0.3762
# 60:	[0s / 4s],		train_loss: 0.3563
# 61:	[0s / 4s],		train_loss: 0.3735
# 62:	[0s / 4s],		train_loss: 0.3710
# 63:	[0s / 5s],		train_loss: 0.3558
# 64:	[0s / 5s],		train_loss: 0.3608
# 65:	[0s / 5s],		train_loss: 0.3677
# 66:	[0s / 5s],		train_loss: 0.3648
# 67:	[0s / 5s],		train_loss: 0.3802
# 68:	[0s / 5s],		train_loss: 0.3661
# 69:	[0s / 5s],		train_loss: 0.3583
# 70:	[0s / 5s],		train_loss: 0.3479
# 71:	[0s / 5s],		train_loss: 0.3608
# 72:	[0s / 5s],		train_loss: 0.3720
# 73:	[0s / 5s],		train_loss: 0.3578
# 74:	[0s / 6s],		train_loss: 0.3491
# 75:	[0s / 6s],		train_loss: 0.3804
# 76:	[0s / 6s],		train_loss: 0.3532
# 77:	[0s / 6s],		train_loss: 0.3568
# 78:	[0s / 6s],		train_loss: 0.3640
# 79:	[0s / 6s],		train_loss: 0.3400
# 80:	[0s / 6s],		train_loss: 0.3513
# 81:	[0s / 6s],		train_loss: 0.3483
# 82:	[0s / 6s],		train_loss: 0.3438
# 83:	[0s / 6s],		train_loss: 0.3609
# 84:	[0s / 6s],		train_loss: 0.3331
# 85:	[0s / 7s],		train_loss: 0.3533
# 86:	[0s / 7s],		train_loss: 0.3356
# 87:	[0s / 7s],		train_loss: 0.3288
# 88:	[0s / 7s],		train_loss: 0.3311
# 89:	[0s / 7s],		train_loss: 0.3448
# 90:	[0s / 7s],		train_loss: 0.3410
# 91:	[0s / 7s],		train_loss: 0.3525
# 92:	[0s / 7s],		train_loss: 0.3311
# 93:	[0s / 7s],		train_loss: 0.3311
# 94:	[0s / 7s],		train_loss: 0.3361
# 95:	[0s / 7s],		train_loss: 0.3238
# 96:	[0s / 7s],		train_loss: 0.3283
# 97:	[0s / 8s],		train_loss: 0.3367
# 98:	[0s / 8s],		train_loss: 0.3389
# 99:	[0s / 8s],		train_loss: 0.3489
# 0:	[0s / 0s],		train_loss: 1.1695
# 1:	[0s / 0s],		train_loss: 0.7780
# 2:	[0s / 0s],		train_loss: 0.6490
# 3:	[0s / 0s],		train_loss: 0.5415
# 4:	[0s / 0s],		train_loss: 0.4911
# 5:	[0s / 0s],		train_loss: 0.4530
# 6:	[0s / 1s],		train_loss: 0.4490
# 7:	[0s / 1s],		train_loss: 0.4420
# 8:	[0s / 1s],		train_loss: 0.4307
# 9:	[0s / 1s],		train_loss: 0.4387
# 10:	[0s / 1s],		train_loss: 0.4381
# 11:	[0s / 1s],		train_loss: 0.4352
# 12:	[0s / 2s],		train_loss: 0.4364
# 13:	[0s / 2s],		train_loss: 0.4368
# 14:	[0s / 2s],		train_loss: 0.4237
# 15:	[0s / 2s],		train_loss: 0.4340
# 16:	[0s / 2s],		train_loss: 0.4221
# 17:	[0s / 2s],		train_loss: 0.4210
# 18:	[0s / 2s],		train_loss: 0.4318
# 19:	[0s / 3s],		train_loss: 0.4269
# 20:	[0s / 3s],		train_loss: 0.4280
# 21:	[0s / 3s],		train_loss: 0.4155
# 22:	[0s / 3s],		train_loss: 0.4265
# 23:	[0s / 3s],		train_loss: 0.4227
# 24:	[0s / 3s],		train_loss: 0.4232
# 25:	[0s / 3s],		train_loss: 0.4246
# 26:	[0s / 4s],		train_loss: 0.4303
# 27:	[0s / 4s],		train_loss: 0.4188
# 28:	[0s / 4s],		train_loss: 0.4198
# 29:	[0s / 4s],		train_loss: 0.4193
# 30:	[0s / 4s],		train_loss: 0.4162
# 31:	[0s / 4s],		train_loss: 0.4135
# 32:	[0s / 4s],		train_loss: 0.4233
# 33:	[0s / 5s],		train_loss: 0.4207
# 34:	[0s / 5s],		train_loss: 0.4189
# 35:	[0s / 5s],		train_loss: 0.4093
# 36:	[0s / 5s],		train_loss: 0.4205
# 37:	[0s / 5s],		train_loss: 0.4134
# 38:	[0s / 5s],		train_loss: 0.4189
# 39:	[0s / 6s],		train_loss: 0.4168
# 40:	[0s / 6s],		train_loss: 0.4143
# 41:	[0s / 6s],		train_loss: 0.4138
# 42:	[0s / 6s],		train_loss: 0.4082
# 43:	[0s / 6s],		train_loss: 0.4105
# 44:	[0s / 6s],		train_loss: 0.4179
# 45:	[0s / 6s],		train_loss: 0.4238
# 46:	[0s / 7s],		train_loss: 0.4098
# 47:	[0s / 7s],		train_loss: 0.4016
# 48:	[0s / 7s],		train_loss: 0.4094
# 49:	[0s / 7s],		train_loss: 0.4073
# 50:	[0s / 7s],		train_loss: 0.4029
# 51:	[0s / 7s],		train_loss: 0.4098
# 52:	[0s / 7s],		train_loss: 0.4241
# 53:	[0s / 8s],		train_loss: 0.4163
# 54:	[0s / 8s],		train_loss: 0.4468
# 55:	[0s / 8s],		train_loss: 0.4510
# 56:	[0s / 8s],		train_loss: 0.4693
# 57:	[0s / 8s],		train_loss: 0.4479
# 58:	[0s / 8s],		train_loss: 0.5150
# 59:	[0s / 8s],		train_loss: 0.5048
# 60:	[0s / 9s],		train_loss: 0.4792
# 61:	[0s / 9s],		train_loss: 0.4543
# 62:	[0s / 9s],		train_loss: 0.4371
# 63:	[0s / 9s],		train_loss: 0.4324
# 64:	[0s / 9s],		train_loss: 0.4371
# 65:	[0s / 9s],		train_loss: 0.4367
# 66:	[0s / 9s],		train_loss: 0.4180
# 67:	[0s / 10s],		train_loss: 0.4184
# 68:	[0s / 10s],		train_loss: 0.4213
# 69:	[0s / 10s],		train_loss: 0.4040
# 70:	[0s / 10s],		train_loss: 0.3923
# 71:	[0s / 10s],		train_loss: 0.3968
# 72:	[0s / 10s],		train_loss: 0.3968
# 73:	[0s / 10s],		train_loss: 0.3940
# 74:	[0s / 11s],		train_loss: 0.3962
# 75:	[0s / 11s],		train_loss: 0.3939
# 76:	[0s / 11s],		train_loss: 0.3795
# 77:	[0s / 11s],		train_loss: 0.3759
# 78:	[0s / 11s],		train_loss: 0.3824
# 79:	[0s / 11s],		train_loss: 0.3801
# 80:	[0s / 12s],		train_loss: 0.3832
# 81:	[0s / 12s],		train_loss: 0.3892
# 82:	[0s / 12s],		train_loss: 0.4296
# 83:	[0s / 12s],		train_loss: 0.4535
# 84:	[0s / 12s],		train_loss: 0.7279
# 85:	[0s / 12s],		train_loss: 4.6656
# 86:	[0s / 12s],		train_loss: 9.3101
# 87:	[0s / 13s],		train_loss: 25.7932
# 88:	[0s / 13s],		train_loss: 34.0997
# 89:	[0s / 13s],		train_loss: 22.8387
# 90:	[0s / 13s],		train_loss: 37.7394
# 91:	[0s / 13s],		train_loss: 34.9817
# 92:	[0s / 14s],		train_loss: 39.4611
# 93:	[0s / 14s],		train_loss: 42.0489
# 94:	[0s / 14s],		train_loss: 40.2749
# 95:	[0s / 14s],		train_loss: 43.7602
# 96:	[0s / 14s],		train_loss: 36.4227
# 97:	[0s / 14s],		train_loss: 35.9841
# 98:	[0s / 15s],		train_loss: 37.6908
# 99:	[0s / 15s],		train_loss: 38.8885

# %% [markdown]
# # III. Results

# %% [markdown]
# We output the AUC value at 5 and 10 years and Uno's C-index at 5 and 10 years, with standard deviation among the 5 folds.

# %%
mean_all = results_all.mean(axis=0)
std_all = results_all.std(axis=0, ddof=0)
measures = pd.concat([mean_all.rename('mean'), std_all.rename('std')],axis = 1)
measures
# Out:
#             mean       std
# unoc5   0.621804  0.071709
# unoc10  0.585146  0.050832
# ibs     0.223809  0.065912
