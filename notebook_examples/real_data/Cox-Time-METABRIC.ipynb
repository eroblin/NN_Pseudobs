# %%
import os
main = os.chdir(os.path.dirname(os.path.dirname(os.getcwd())))

# %%
import json
import numpy as np
import pandas as pd

from model import model_architecture, output_results, utils
from pycox.models import CoxTime
from pycox.models.cox_time import MLPVanillaCoxTime
from sksurv.util import Surv as skSurv
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # I. METABRIC data

# %% [markdown]
# We use METABRIC data. We use clinical and pathological informations and gene expression data. Missing values for explanatory variables are completed. Data is first splitted into 5 folds for the double 5 folds cross validation.  The same 5 folds are used for all the models and are stored in the file "folds.json".

# %%
name = "CoxTime"

# %%
df = pd.read_csv("data/real_data/metabric_imputed.csv")

# %%
with open('data/real_data/folds.json') as f:
        kfolds = json.load(f)

# %% [markdown]
# # II. Model's construction and training

# %% [markdown]
# The parameters of the architecture are the one listed in the parameters dataframe, selected by a double 5-fold cross-validation among 400 sets of parameters. There are 5 sets of parameters, corresponding to each fold of the outerloop.

# %%
results_all = pd.DataFrame(columns=['unoc5', 'unoc10','ibs'])

k=0
for kname, val in kfolds.items():
    param = pd.read_csv('model/best_param_metabric/'+name+'_best_param.csv', sep = ";",index_col=0)
    train_index = val['train']
    val_index = val['test']
    
    df_train, df_val = df.iloc[train_index], df.iloc[val_index]
    
    list_all_cols = df.drop(columns = ['yy','status'],axis=1).columns.to_list()
    cols_leave = ['N', 'grade1','grade2', 'hormonotherapy', 'chemotherapy']
    cols_standardize = [col for col in list_all_cols if col not in cols_leave] 
    standardize = [([col], StandardScaler()) for col in cols_standardize]
    leave = [(col, None) for col in cols_leave]
    df_mapper = DataFrameMapper(standardize + leave, df_out = True)
    
    X_train = df_train.drop(["yy","status"], axis = 1)
    X_train = df_mapper.fit_transform(X_train).astype('float32')
    X_val = df_val.drop(["yy","status"], axis = 1)
    X_val = df_mapper.transform(X_val).astype('float32')

    if name=="DeepHit":
        num_durations = 10 
        labtrans = DeepHitSingle.label_transform(num_durations)
        y_train = labtrans.fit_transform(*(df_train['yy'].values, df_train['status'].values))
    elif name=="CoxTime":
        labtrans = CoxTime.label_transform()
        y_train = labtrans.fit_transform(*(df_train['yy'].values, df_train['status'].values))
    else:
        labtrans=""
        y_train = (df_train['yy'].values, df_train['status'].values)

    model,callbacks  = model_architecture.build_model(np.array(X_train), 
                               param['neurons'][kname], 
                               param['dropout'][kname], 
                               param['activation'][kname],
                               param['lr'][kname],
                               param['optimizer'][kname],
                               param['n_layers'][kname],
                               name,
                               labtrans)
    log = model.fit(np.array(X_train), 
                     y_train,
                    int(param['batch_size'][kname]),
                     epochs=100, 
                     callbacks = callbacks, 
                     verbose = True)
    _ = model.compute_baseline_hazards()
    surv = model.predict_surv_df(np.array(X_val))
    res = output_results.output_stats(model,surv,X_train, df_train, X_val, df_val)
    results_all = results_all.append(res, ignore_index  = True, sort = False)
    k+=1
# Out:
# 0:	[0s / 0s],		train_loss: 0.7810
# 1:	[0s / 0s],		train_loss: 0.7401
# 2:	[0s / 0s],		train_loss: 0.7148
# 3:	[0s / 0s],		train_loss: 0.6741
# 4:	[0s / 0s],		train_loss: 0.7285
# 5:	[0s / 0s],		train_loss: 0.7105
# 6:	[0s / 0s],		train_loss: 0.6923
# 7:	[0s / 0s],		train_loss: 0.7013
# 8:	[0s / 0s],		train_loss: 0.6707
# 9:	[0s / 0s],		train_loss: 0.7168
# 10:	[0s / 0s],		train_loss: 0.6702
# 11:	[0s / 0s],		train_loss: 0.6574
# 12:	[0s / 0s],		train_loss: 0.6816
# 13:	[0s / 0s],		train_loss: 0.6727
# 14:	[0s / 0s],		train_loss: 0.6707
# 15:	[0s / 0s],		train_loss: 0.6437
# 16:	[0s / 0s],		train_loss: 0.6938
# 17:	[0s / 0s],		train_loss: 0.7307
# 18:	[0s / 0s],		train_loss: 0.6799
# 19:	[0s / 0s],		train_loss: 0.6184
# 20:	[0s / 0s],		train_loss: 0.6557
# 21:	[0s / 0s],		train_loss: 0.6109
# 22:	[0s / 0s],		train_loss: 0.6171
# 23:	[0s / 0s],		train_loss: 0.6487
# 24:	[0s / 1s],		train_loss: 0.6047
# 25:	[0s / 1s],		train_loss: 0.6313
# 26:	[0s / 1s],		train_loss: 0.6088
# 27:	[0s / 1s],		train_loss: 0.6141
# 28:	[0s / 1s],		train_loss: 0.5782
# 29:	[0s / 1s],		train_loss: 0.6053
# 30:	[0s / 1s],		train_loss: 0.5653
# 31:	[0s / 1s],		train_loss: 0.5906
# 32:	[0s / 1s],		train_loss: 0.6344
# 33:	[0s / 1s],		train_loss: 0.6355
# 34:	[0s / 1s],		train_loss: 0.6563
# 35:	[0s / 1s],		train_loss: 0.5746
# 36:	[0s / 1s],		train_loss: 0.6236
# 37:	[0s / 1s],		train_loss: 0.6552
# 38:	[0s / 1s],		train_loss: 0.6508
# 39:	[0s / 1s],		train_loss: 0.6283
# 40:	[0s / 1s],		train_loss: 0.6561
# 41:	[0s / 1s],		train_loss: 0.6366
# 42:	[0s / 1s],		train_loss: 0.5644
# 43:	[0s / 1s],		train_loss: 0.6046
# 44:	[0s / 1s],		train_loss: 0.5678
# 45:	[0s / 1s],		train_loss: 0.5292
# 46:	[0s / 1s],		train_loss: 0.5746
# 47:	[0s / 1s],		train_loss: 0.5580
# 48:	[0s / 2s],		train_loss: 0.5751
# 49:	[0s / 2s],		train_loss: 0.5345
# 50:	[0s / 2s],		train_loss: 0.5706
# 51:	[0s / 2s],		train_loss: 0.5156
# 52:	[0s / 2s],		train_loss: 0.5325
# 53:	[0s / 2s],		train_loss: 0.5232
# 54:	[0s / 2s],		train_loss: 0.5874
# 55:	[0s / 2s],		train_loss: 0.5127
# 56:	[0s / 2s],		train_loss: 0.5190
# 57:	[0s / 2s],		train_loss: 0.5148
# 58:	[0s / 2s],		train_loss: 0.4906
# 59:	[0s / 2s],		train_loss: 0.4999
# 60:	[0s / 2s],		train_loss: 0.5352
# 61:	[0s / 2s],		train_loss: 0.5192
# 62:	[0s / 2s],		train_loss: 0.5199
# 63:	[0s / 2s],		train_loss: 0.5107
# 64:	[0s / 2s],		train_loss: 0.5451
# 65:	[0s / 2s],		train_loss: 0.5195
# 66:	[0s / 2s],		train_loss: 0.5934
# 67:	[0s / 2s],		train_loss: 0.5453
# 68:	[0s / 2s],		train_loss: 0.5713
# 69:	[0s / 2s],		train_loss: 0.5287
# 70:	[0s / 2s],		train_loss: 0.5928
# 71:	[0s / 3s],		train_loss: 0.5112
# 72:	[0s / 3s],		train_loss: 0.5458
# 73:	[0s / 3s],		train_loss: 0.5379
# 74:	[0s / 3s],		train_loss: 0.5449
# 75:	[0s / 3s],		train_loss: 0.6012
# 76:	[0s / 3s],		train_loss: 0.5301
# 77:	[0s / 3s],		train_loss: 0.4649
# 78:	[0s / 3s],		train_loss: 0.5624
# 79:	[0s / 3s],		train_loss: 0.4982
# 80:	[0s / 3s],		train_loss: 0.5108
# 81:	[0s / 3s],		train_loss: 0.5251
# 82:	[0s / 3s],		train_loss: 0.5109
# 83:	[0s / 3s],		train_loss: 0.4818
# 84:	[0s / 3s],		train_loss: 0.5106
# 85:	[0s / 3s],		train_loss: 0.4714
# 86:	[0s / 3s],		train_loss: 0.4587
# 87:	[0s / 3s],		train_loss: 0.4739
# 88:	[0s / 3s],		train_loss: 0.4734
# 89:	[0s / 3s],		train_loss: 0.4098
# 90:	[0s / 3s],		train_loss: 0.4856
# 91:	[0s / 3s],		train_loss: 0.4397
# 92:	[0s / 3s],		train_loss: 0.4397
# 93:	[0s / 3s],		train_loss: 0.4544
# 94:	[0s / 3s],		train_loss: 0.4557
# 95:	[0s / 3s],		train_loss: 0.4651
# 96:	[0s / 4s],		train_loss: 0.4664
# 97:	[0s / 4s],		train_loss: 0.4390
# 98:	[0s / 4s],		train_loss: 0.4559
# 99:	[0s / 4s],		train_loss: 0.4583
# 0:	[0s / 0s],		train_loss: 0.7759
# 1:	[0s / 0s],		train_loss: 0.7355
# 2:	[0s / 0s],		train_loss: 0.7049
# 3:	[0s / 0s],		train_loss: 0.6939
# 4:	[0s / 0s],		train_loss: 0.7025
# 5:	[0s / 0s],		train_loss: 0.6873
# 6:	[0s / 0s],		train_loss: 0.6935
# 7:	[0s / 0s],		train_loss: 0.6900
# 8:	[0s / 0s],		train_loss: 0.6931
# 9:	[0s / 0s],		train_loss: 0.6817
# 10:	[0s / 0s],		train_loss: 0.6710
# 11:	[0s / 0s],		train_loss: 0.6795
# 12:	[0s / 0s],		train_loss: 0.6733
# 13:	[0s / 0s],		train_loss: 0.6722
# 14:	[0s / 0s],		train_loss: 0.6725
# 15:	[0s / 0s],		train_loss: 0.6892
# 16:	[0s / 0s],		train_loss: 0.6822
# 17:	[0s / 0s],		train_loss: 0.6629
# 18:	[0s / 0s],		train_loss: 0.6595
# 19:	[0s / 1s],		train_loss: 0.6603
# 20:	[0s / 1s],		train_loss: 0.6599
# 21:	[0s / 1s],		train_loss: 0.6517
# 22:	[0s / 1s],		train_loss: 0.6538
# 23:	[0s / 1s],		train_loss: 0.6412
# 24:	[0s / 1s],		train_loss: 0.6392
# 25:	[0s / 1s],		train_loss: 0.6508
# 26:	[0s / 1s],		train_loss: 0.6337
# 27:	[0s / 1s],		train_loss: 0.6230
# 28:	[0s / 1s],		train_loss: 0.6395
# 29:	[0s / 1s],		train_loss: 0.6325
# 30:	[0s / 1s],		train_loss: 0.6480
# 31:	[0s / 1s],		train_loss: 0.6392
# 32:	[0s / 1s],		train_loss: 0.6273
# 33:	[0s / 1s],		train_loss: 0.6137
# 34:	[0s / 1s],		train_loss: 0.6429
# 35:	[0s / 1s],		train_loss: 0.6309
# 36:	[0s / 1s],		train_loss: 0.6108
# 37:	[0s / 1s],		train_loss: 0.5952
# 38:	[0s / 1s],		train_loss: 0.6237
# 39:	[0s / 2s],		train_loss: 0.5827
# 40:	[0s / 2s],		train_loss: 0.5702
# 41:	[0s / 2s],		train_loss: 0.5732
# 42:	[0s / 2s],		train_loss: 0.5918
# 43:	[0s / 2s],		train_loss: 0.5951
# 44:	[0s / 2s],		train_loss: 0.5904
# 45:	[0s / 2s],		train_loss: 0.5796
# 46:	[0s / 2s],		train_loss: 0.5688
# 47:	[0s / 2s],		train_loss: 0.5633
# 48:	[0s / 2s],		train_loss: 0.5429
# 49:	[0s / 2s],		train_loss: 0.5409
# 50:	[0s / 2s],		train_loss: 0.5564
# 51:	[0s / 2s],		train_loss: 0.5358
# 52:	[0s / 2s],		train_loss: 0.5676
# 53:	[0s / 2s],		train_loss: 0.5532
# 54:	[0s / 2s],		train_loss: 0.5702
# 55:	[0s / 2s],		train_loss: 0.5750
# 56:	[0s / 2s],		train_loss: 0.5305
# 57:	[0s / 2s],		train_loss: 0.5128
# 58:	[0s / 3s],		train_loss: 0.5254
# 59:	[0s / 3s],		train_loss: 0.5429
# 60:	[0s / 3s],		train_loss: 0.5322
# 61:	[0s / 3s],		train_loss: 0.5499
# 62:	[0s / 3s],		train_loss: 0.5510
# 63:	[0s / 3s],		train_loss: 0.5308
# 64:	[0s / 3s],		train_loss: 0.5597
# 65:	[0s / 3s],		train_loss: 0.5464
# 66:	[0s / 3s],		train_loss: 0.5137
# 67:	[0s / 3s],		train_loss: 0.5080
# 68:	[0s / 3s],		train_loss: 0.5345
# 69:	[0s / 3s],		train_loss: 0.5441
# 70:	[0s / 3s],		train_loss: 0.5159
# 71:	[0s / 3s],		train_loss: 0.5154
# 72:	[0s / 3s],		train_loss: 0.5204
# 73:	[0s / 3s],		train_loss: 0.5034
# 74:	[0s / 3s],		train_loss: 0.5152
# 75:	[0s / 4s],		train_loss: 0.5025
# 76:	[0s / 4s],		train_loss: 0.4684
# 77:	[0s / 4s],		train_loss: 0.4945
# 78:	[0s / 4s],		train_loss: 0.4947
# 79:	[0s / 4s],		train_loss: 0.4716
# 80:	[0s / 4s],		train_loss: 0.5033
# 81:	[0s / 4s],		train_loss: 0.4423
# 82:	[0s / 4s],		train_loss: 0.4641
# 83:	[0s / 4s],		train_loss: 0.4656
# 84:	[0s / 4s],		train_loss: 0.4558
# 85:	[0s / 4s],		train_loss: 0.4637
# 86:	[0s / 4s],		train_loss: 0.4517
# 87:	[0s / 4s],		train_loss: 0.4675
# 88:	[0s / 4s],		train_loss: 0.4748
# 89:	[0s / 4s],		train_loss: 0.4289
# 90:	[0s / 4s],		train_loss: 0.4303
# 91:	[0s / 5s],		train_loss: 0.4328
# 92:	[0s / 5s],		train_loss: 0.4466
# 93:	[0s / 5s],		train_loss: 0.4071
# 94:	[0s / 5s],		train_loss: 0.4445
# 95:	[0s / 5s],		train_loss: 0.4319
# 96:	[0s / 5s],		train_loss: 0.4274
# 97:	[0s / 5s],		train_loss: 0.4320
# 98:	[0s / 5s],		train_loss: 0.4329
# 99:	[0s / 5s],		train_loss: 0.4446
# 0:	[0s / 0s],		train_loss: 0.9275
# 1:	[0s / 0s],		train_loss: 0.7592
# 2:	[0s / 0s],		train_loss: 0.7149
# 3:	[0s / 0s],		train_loss: 0.6470
# 4:	[0s / 0s],		train_loss: 0.6477
# 5:	[0s / 0s],		train_loss: 0.6285
# 6:	[0s / 0s],		train_loss: 0.6223
# 7:	[0s / 0s],		train_loss: 0.6226
# 8:	[0s / 0s],		train_loss: 0.6164
# 9:	[0s / 0s],		train_loss: 0.6444
# 10:	[0s / 0s],		train_loss: 0.6334
# 11:	[0s / 0s],		train_loss: 0.6153
# 12:	[0s / 0s],		train_loss: 0.6016
# 13:	[0s / 0s],		train_loss: 0.5976
# 14:	[0s / 0s],		train_loss: 0.5816
# 15:	[0s / 0s],		train_loss: 0.6017
# 16:	[0s / 0s],		train_loss: 0.5962
# 17:	[0s / 0s],		train_loss: 0.5880
# 18:	[0s / 0s],		train_loss: 0.6223
# 19:	[0s / 0s],		train_loss: 0.5599
# 20:	[0s / 0s],		train_loss: 0.5835
# 21:	[0s / 0s],		train_loss: 0.5644
# 22:	[0s / 0s],		train_loss: 0.5742
# 23:	[0s / 0s],		train_loss: 0.5453
# 24:	[0s / 0s],		train_loss: 0.5865
# 25:	[0s / 0s],		train_loss: 0.5712
# 26:	[0s / 0s],		train_loss: 0.5941
# 27:	[0s / 0s],		train_loss: 0.5504
# 28:	[0s / 0s],		train_loss: 0.5939
# 29:	[0s / 0s],		train_loss: 0.5652
# 30:	[0s / 1s],		train_loss: 0.5983
# 31:	[0s / 1s],		train_loss: 0.5661
# 32:	[0s / 1s],		train_loss: 0.5535
# 33:	[0s / 1s],		train_loss: 0.5450
# 34:	[0s / 1s],		train_loss: 0.5732
# 35:	[0s / 1s],		train_loss: 0.5631
# 36:	[0s / 1s],		train_loss: 0.5325
# 37:	[0s / 1s],		train_loss: 0.5462
# 38:	[0s / 1s],		train_loss: 0.5496
# 39:	[0s / 1s],		train_loss: 0.5523
# 40:	[0s / 1s],		train_loss: 0.5355
# 41:	[0s / 1s],		train_loss: 0.5295
# 42:	[0s / 1s],		train_loss: 0.5064
# 43:	[0s / 1s],		train_loss: 0.5762
# 44:	[0s / 1s],		train_loss: 0.5794
# 45:	[0s / 1s],		train_loss: 0.5473
# 46:	[0s / 1s],		train_loss: 0.5558
# 47:	[0s / 1s],		train_loss: 0.5703
# 48:	[0s / 1s],		train_loss: 0.5890
# 49:	[0s / 1s],		train_loss: 0.5466
# 50:	[0s / 1s],		train_loss: 0.5906
# 51:	[0s / 1s],		train_loss: 0.5661
# 52:	[0s / 1s],		train_loss: 0.5420
# 53:	[0s / 1s],		train_loss: 0.5423
# 54:	[0s / 1s],		train_loss: 0.5500
# 55:	[0s / 1s],		train_loss: 0.5302
# 56:	[0s / 1s],		train_loss: 0.5734
# 57:	[0s / 1s],		train_loss: 0.5584
# 58:	[0s / 1s],		train_loss: 0.5482
# 59:	[0s / 2s],		train_loss: 0.5422
# 60:	[0s / 2s],		train_loss: 0.5509
# 61:	[0s / 2s],		train_loss: 0.5801
# 62:	[0s / 2s],		train_loss: 0.5972
# 63:	[0s / 2s],		train_loss: 0.5513
# 64:	[0s / 2s],		train_loss: 0.5704
# 65:	[0s / 2s],		train_loss: 0.5481
# 66:	[0s / 2s],		train_loss: 0.5383
# 67:	[0s / 2s],		train_loss: 0.5534
# 68:	[0s / 2s],		train_loss: 0.5191
# 69:	[0s / 2s],		train_loss: 0.5160
# 70:	[0s / 2s],		train_loss: 0.5447
# 71:	[0s / 2s],		train_loss: 0.5606
# 72:	[0s / 2s],		train_loss: 0.5556
# 73:	[0s / 2s],		train_loss: 0.5636
# 74:	[0s / 2s],		train_loss: 0.5805
# 75:	[0s / 2s],		train_loss: 0.5453
# 76:	[0s / 2s],		train_loss: 0.5288
# 77:	[0s / 2s],		train_loss: 0.5512
# 78:	[0s / 2s],		train_loss: 0.5553
# 79:	[0s / 2s],		train_loss: 0.5590
# 80:	[0s / 2s],		train_loss: 0.5537
# 81:	[0s / 2s],		train_loss: 0.5875
# 82:	[0s / 2s],		train_loss: 0.5591
# 83:	[0s / 2s],		train_loss: 0.5739
# 84:	[0s / 2s],		train_loss: 0.5668
# 85:	[0s / 2s],		train_loss: 0.5584
# 86:	[0s / 2s],		train_loss: 0.5614
# 87:	[0s / 2s],		train_loss: 0.5384
# 88:	[0s / 2s],		train_loss: 0.5848
# 89:	[0s / 3s],		train_loss: 0.5636
# 90:	[0s / 3s],		train_loss: 0.5550
# 91:	[0s / 3s],		train_loss: 0.5634
# 92:	[0s / 3s],		train_loss: 0.5537
# 93:	[0s / 3s],		train_loss: 0.5452
# 94:	[0s / 3s],		train_loss: 0.5338
# 95:	[0s / 3s],		train_loss: 0.5463
# 96:	[0s / 3s],		train_loss: 0.5408
# 97:	[0s / 3s],		train_loss: 0.5069
# 98:	[0s / 3s],		train_loss: 0.5447
# 99:	[0s / 3s],		train_loss: 0.5640
# 0:	[0s / 0s],		train_loss: 0.7963
# 1:	[0s / 0s],		train_loss: 0.8048
# 2:	[0s / 0s],		train_loss: 0.7569
# 3:	[0s / 0s],		train_loss: 0.7292
# 4:	[0s / 0s],		train_loss: 0.7011
# 5:	[0s / 0s],		train_loss: 0.6939
# 6:	[0s / 0s],		train_loss: 0.7012
# 7:	[0s / 0s],		train_loss: 0.6841
# 8:	[0s / 0s],		train_loss: 0.6900
# 9:	[0s / 0s],		train_loss: 0.7075
# 10:	[0s / 0s],		train_loss: 0.6801
# 11:	[0s / 0s],		train_loss: 0.6748
# 12:	[0s / 0s],		train_loss: 0.6819
# 13:	[0s / 0s],		train_loss: 0.6768
# 14:	[0s / 0s],		train_loss: 0.6862
# 15:	[0s / 0s],		train_loss: 0.6785
# 16:	[0s / 0s],		train_loss: 0.6823
# 17:	[0s / 0s],		train_loss: 0.6909
# 18:	[0s / 0s],		train_loss: 0.6680
# 19:	[0s / 0s],		train_loss: 0.6590
# 20:	[0s / 0s],		train_loss: 0.6617
# 21:	[0s / 0s],		train_loss: 0.6801
# 22:	[0s / 0s],		train_loss: 0.6707
# 23:	[0s / 1s],		train_loss: 0.6585
# 24:	[0s / 1s],		train_loss: 0.6597
# 25:	[0s / 1s],		train_loss: 0.6641
# 26:	[0s / 1s],		train_loss: 0.6579
# 27:	[0s / 1s],		train_loss: 0.6617
# 28:	[0s / 1s],		train_loss: 0.6630
# 29:	[0s / 1s],		train_loss: 0.6449
# 30:	[0s / 1s],		train_loss: 0.6661
# 31:	[0s / 1s],		train_loss: 0.6529
# 32:	[0s / 1s],		train_loss: 0.6801
# 33:	[0s / 1s],		train_loss: 0.6574
# 34:	[0s / 1s],		train_loss: 0.6484
# 35:	[0s / 1s],		train_loss: 0.6488
# 36:	[0s / 1s],		train_loss: 0.6383
# 37:	[0s / 1s],		train_loss: 0.6346
# 38:	[0s / 1s],		train_loss: 0.6410
# 39:	[0s / 1s],		train_loss: 0.6556
# 40:	[0s / 1s],		train_loss: 0.6335
# 41:	[0s / 1s],		train_loss: 0.6412
# 42:	[0s / 1s],		train_loss: 0.6406
# 43:	[0s / 1s],		train_loss: 0.6712
# 44:	[0s / 1s],		train_loss: 0.6390
# 45:	[0s / 1s],		train_loss: 0.6371
# 46:	[0s / 1s],		train_loss: 0.6345
# 47:	[0s / 2s],		train_loss: 0.6085
# 48:	[0s / 2s],		train_loss: 0.6497
# 49:	[0s / 2s],		train_loss: 0.6375
# 50:	[0s / 2s],		train_loss: 0.6169
# 51:	[0s / 2s],		train_loss: 0.6292
# 52:	[0s / 2s],		train_loss: 0.6088
# 53:	[0s / 2s],		train_loss: 0.6105
# 54:	[0s / 2s],		train_loss: 0.6216
# 55:	[0s / 2s],		train_loss: 0.6334
# 56:	[0s / 2s],		train_loss: 0.6200
# 57:	[0s / 2s],		train_loss: 0.6202
# 58:	[0s / 2s],		train_loss: 0.6376
# 59:	[0s / 2s],		train_loss: 0.6278
# 60:	[0s / 2s],		train_loss: 0.6124
# 61:	[0s / 2s],		train_loss: 0.6160
# 62:	[0s / 2s],		train_loss: 0.6232
# 63:	[0s / 2s],		train_loss: 0.6166
# 64:	[0s / 2s],		train_loss: 0.5972
# 65:	[0s / 2s],		train_loss: 0.6150
# 66:	[0s / 2s],		train_loss: 0.6136
# 67:	[0s / 2s],		train_loss: 0.6122
# 68:	[0s / 2s],		train_loss: 0.6261
# 69:	[0s / 3s],		train_loss: 0.6172
# 70:	[0s / 3s],		train_loss: 0.6321
# 71:	[0s / 3s],		train_loss: 0.6060
# 72:	[0s / 3s],		train_loss: 0.6052
# 73:	[0s / 3s],		train_loss: 0.5921
# 74:	[0s / 3s],		train_loss: 0.6054
# 75:	[0s / 3s],		train_loss: 0.6138
# 76:	[0s / 3s],		train_loss: 0.5831
# 77:	[0s / 3s],		train_loss: 0.6199
# 78:	[0s / 3s],		train_loss: 0.6065
# 79:	[0s / 3s],		train_loss: 0.5693
# 80:	[0s / 3s],		train_loss: 0.6075
# 81:	[0s / 3s],		train_loss: 0.5853
# 82:	[0s / 3s],		train_loss: 0.6112
# 83:	[0s / 3s],		train_loss: 0.6065
# 84:	[0s / 3s],		train_loss: 0.5768
# 85:	[0s / 3s],		train_loss: 0.5755
# 86:	[0s / 3s],		train_loss: 0.5663
# 87:	[0s / 3s],		train_loss: 0.5782
# 88:	[0s / 3s],		train_loss: 0.5865
# 89:	[0s / 3s],		train_loss: 0.5481
# 90:	[0s / 3s],		train_loss: 0.5530
# 91:	[0s / 4s],		train_loss: 0.5553
# 92:	[0s / 4s],		train_loss: 0.5597
# 93:	[0s / 4s],		train_loss: 0.5833
# 94:	[0s / 4s],		train_loss: 0.5872
# 95:	[0s / 4s],		train_loss: 0.5989
# 96:	[0s / 4s],		train_loss: 0.5768
# 97:	[0s / 4s],		train_loss: 0.5877
# 98:	[0s / 4s],		train_loss: 0.5438
# 99:	[0s / 4s],		train_loss: 0.5630
# 0:	[0s / 0s],		train_loss: 0.8814
# 1:	[0s / 0s],		train_loss: 0.7479
# 2:	[0s / 0s],		train_loss: 0.7271
# 3:	[0s / 0s],		train_loss: 0.6519
# 4:	[0s / 0s],		train_loss: 0.6530
# 5:	[0s / 0s],		train_loss: 0.6446
# 6:	[0s / 0s],		train_loss: 0.6367
# 7:	[0s / 0s],		train_loss: 0.6252
# 8:	[0s / 0s],		train_loss: 0.6366
# 9:	[0s / 0s],		train_loss: 0.6005
# 10:	[0s / 0s],		train_loss: 0.5779
# 11:	[0s / 0s],		train_loss: 0.5641
# 12:	[0s / 0s],		train_loss: 0.6058
# 13:	[0s / 0s],		train_loss: 0.5463
# 14:	[0s / 0s],		train_loss: 0.5945
# 15:	[0s / 0s],		train_loss: 0.5290
# 16:	[0s / 0s],		train_loss: 0.5497
# 17:	[0s / 0s],		train_loss: 0.5361
# 18:	[0s / 0s],		train_loss: 0.5511
# 19:	[0s / 0s],		train_loss: 0.5092
# 20:	[0s / 0s],		train_loss: 0.5203
# 21:	[0s / 0s],		train_loss: 0.5029
# 22:	[0s / 0s],		train_loss: 0.5011
# 23:	[0s / 0s],		train_loss: 0.4919
# 24:	[0s / 1s],		train_loss: 0.4880
# 25:	[0s / 1s],		train_loss: 0.4691
# 26:	[0s / 1s],		train_loss: 0.4842
# 27:	[0s / 1s],		train_loss: 0.5010
# 28:	[0s / 1s],		train_loss: 0.4455
# 29:	[0s / 1s],		train_loss: 0.4655
# 30:	[0s / 1s],		train_loss: 0.4499
# 31:	[0s / 1s],		train_loss: 0.4481
# 32:	[0s / 1s],		train_loss: 0.4004
# 33:	[0s / 1s],		train_loss: 0.4191
# 34:	[0s / 1s],		train_loss: 0.3684
# 35:	[0s / 1s],		train_loss: 0.4030
# 36:	[0s / 1s],		train_loss: 0.4222
# 37:	[0s / 1s],		train_loss: 0.4061
# 38:	[0s / 1s],		train_loss: 0.3832
# 39:	[0s / 1s],		train_loss: 0.4010
# 40:	[0s / 1s],		train_loss: 0.3956
# 41:	[0s / 1s],		train_loss: 0.4122
# 42:	[0s / 1s],		train_loss: 0.4212
# 43:	[0s / 1s],		train_loss: 0.4050
# 44:	[0s / 1s],		train_loss: 0.3561
# 45:	[0s / 1s],		train_loss: 0.4107
# 46:	[0s / 1s],		train_loss: 0.3707
# 47:	[0s / 1s],		train_loss: 0.3799
# 48:	[0s / 2s],		train_loss: 0.3824
# 49:	[0s / 2s],		train_loss: 0.3923
# 50:	[0s / 2s],		train_loss: 0.3818
# 51:	[0s / 2s],		train_loss: 0.3462
# 52:	[0s / 2s],		train_loss: 0.3963
# 53:	[0s / 2s],		train_loss: 0.3641
# 54:	[0s / 2s],		train_loss: 0.3569
# 55:	[0s / 2s],		train_loss: 0.3505
# 56:	[0s / 2s],		train_loss: 0.3870
# 57:	[0s / 2s],		train_loss: 0.3312
# 58:	[0s / 2s],		train_loss: 0.3409
# 59:	[0s / 2s],		train_loss: 0.3130
# 60:	[0s / 2s],		train_loss: 0.3468
# 61:	[0s / 2s],		train_loss: 0.3316
# 62:	[0s / 2s],		train_loss: 0.3422
# 63:	[0s / 2s],		train_loss: 0.3135
# 64:	[0s / 2s],		train_loss: 0.3095
# 65:	[0s / 2s],		train_loss: 0.2917
# 66:	[0s / 2s],		train_loss: 0.3644
# 67:	[0s / 2s],		train_loss: 0.3069
# 68:	[0s / 2s],		train_loss: 0.3271
# 69:	[0s / 2s],		train_loss: 0.3220
# 70:	[0s / 2s],		train_loss: 0.3026
# 71:	[0s / 2s],		train_loss: 0.2909
# 72:	[0s / 3s],		train_loss: 0.3255
# 73:	[0s / 3s],		train_loss: 0.3083
# 74:	[0s / 3s],		train_loss: 0.3235
# 75:	[0s / 3s],		train_loss: 0.2946
# 76:	[0s / 3s],		train_loss: 0.2974
# 77:	[0s / 3s],		train_loss: 0.3294
# 78:	[0s / 3s],		train_loss: 0.3050
# 79:	[0s / 3s],		train_loss: 0.2987
# 80:	[0s / 3s],		train_loss: 0.3034
# 81:	[0s / 3s],		train_loss: 0.3355
# 82:	[0s / 3s],		train_loss: 0.3165
# 83:	[0s / 3s],		train_loss: 0.2826
# 84:	[0s / 3s],		train_loss: 0.3463
# 85:	[0s / 3s],		train_loss: 0.3384
# 86:	[0s / 3s],		train_loss: 0.3039
# 87:	[0s / 3s],		train_loss: 0.3136
# 88:	[0s / 3s],		train_loss: 0.2895
# 89:	[0s / 3s],		train_loss: 0.2938
# 90:	[0s / 3s],		train_loss: 0.3076
# 91:	[0s / 3s],		train_loss: 0.2752
# 92:	[0s / 3s],		train_loss: 0.2613
# 93:	[0s / 3s],		train_loss: 0.2473
# 94:	[0s / 3s],		train_loss: 0.2995
# 95:	[0s / 3s],		train_loss: 0.2943
# 96:	[0s / 4s],		train_loss: 0.2919
# 97:	[0s / 4s],		train_loss: 0.2935
# 98:	[0s / 4s],		train_loss: 0.2784
# 99:	[0s / 4s],		train_loss: 0.2690

# %% [markdown]
# # III. Results

# %% [markdown]
# We output the AUC value at 5 and 10 years and Uno's C-index at 5 and 10 years, with standard deviation among the 5 folds.

# %%
mean_all = results_all.mean(axis=0)
std_all = results_all.std(axis=0, ddof=0)
measures = pd.concat([mean_all.rename('mean'), std_all.rename('std')],axis = 1)
measures
# Out:
#             mean       std
# unoc5   0.667228  0.039833
# unoc10  0.639136  0.031863
# ibs     0.200904  0.022129
