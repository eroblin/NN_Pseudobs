# %%
import os
main = os.chdir(os.path.dirname(os.path.dirname(os.getcwd())))

# %%
import json
import numpy as np
import pandas as pd

from model import model_architecture, output_results, utils
from sksurv.util import Surv as skSurv
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # I. METABRIC data

# %% [markdown]
# We use METABRIC data. We use clinical and pathological informations and gene expression data. Missing values for explanatory variables are completed. Data is first splitted into 5 folds for the double 5 folds cross validation.  The same 5 folds are used for all the models and are stored in the file "folds.json".

# %%
name = "CoxCC"

# %%
df = pd.read_csv("data/real_data/metabric_imputed.csv")

# %%
with open('data/real_data/folds.json') as f:
        kfolds = json.load(f)

# %% [markdown]
# # II. Model's construction and training

# %% [markdown]
# The parameters of the architecture are the one listed in the parameters dataframe, selected by a double 5-fold cross-validation among 400 sets of parameters. There are 5 sets of parameters, corresponding to each fold of the outerloop.

# %%
results_all = pd.DataFrame(columns=['unoc5', 'unoc10','ibs'])

k=0
for kname, val in kfolds.items():
    param = pd.read_csv('model/best_param_metabric/'+name+'_best_param.csv', sep = ";",index_col=0)
    train_index = val['train']
    val_index = val['test']
    
    df_train, df_val = df.iloc[train_index], df.iloc[val_index]
    
    list_all_cols = df.drop(columns = ['yy','status'],axis=1).columns.to_list()
    cols_leave = ['N', 'grade1','grade2', 'hormonotherapy', 'chemotherapy']
    cols_standardize = [col for col in list_all_cols if col not in cols_leave] 
    standardize = [([col], StandardScaler()) for col in cols_standardize]
    leave = [(col, None) for col in cols_leave]
    df_mapper = DataFrameMapper(standardize + leave, df_out = True)
    
    X_train = df_train.drop(["yy","status"], axis = 1)
    X_train = df_mapper.fit_transform(X_train).astype('float32')
    X_val = df_val.drop(["yy","status"], axis = 1)
    X_val = df_mapper.transform(X_val).astype('float32')

    if name=="DeepHit":
        num_durations = 10 
        labtrans = DeepHitSingle.label_transform(num_durations)
        y_train = labtrans.fit_transform(*(df_train['yy'].values, df_train['status'].values))
    elif name=="CoxTime":
        labtrans = CoxTime.label_transform()
        y_train = labtrans.fit_transform(*(df_train['yy'].values, df_train['status'].values))
    else:
        labtrans=""
        y_train = (df_train['yy'].values, df_train['status'].values)

    model,callbacks  = model_architecture.build_model(np.array(X_train), 
                               param['neurons'][kname], 
                               param['dropout'][kname], 
                               param['activation'][kname],
                               param['lr'][kname],
                               param['optimizer'][kname],
                               param['n_layers'][kname],
                               name,
                               labtrans)
    log = model.fit(np.array(X_train), 
                     y_train,
                    int(param['batch_size'][kname]),
                     epochs=100, 
                     callbacks = callbacks, 
                     verbose = True)
    _ = model.compute_baseline_hazards()
    surv = model.predict_surv_df(np.array(X_val))
    res = output_results.output_stats(model,surv,X_train, df_train, X_val, df_val)
    results_all = results_all.append(res, ignore_index  = True, sort = False)
    k+=1
# Out:
# 0:	[0s / 0s],		train_loss: 6.1692
# 1:	[0s / 0s],		train_loss: 7.7759
# 2:	[0s / 0s],		train_loss: 1.4317
# 3:	[0s / 0s],		train_loss: 0.8203
# 4:	[0s / 0s],		train_loss: 0.9107
# 5:	[0s / 0s],		train_loss: 0.6984
# 6:	[0s / 0s],		train_loss: 0.6807
# 7:	[0s / 0s],		train_loss: 0.6952
# 8:	[0s / 0s],		train_loss: 0.6996
# 9:	[0s / 0s],		train_loss: 0.6916
# 10:	[0s / 0s],		train_loss: 0.6928
# 11:	[0s / 0s],		train_loss: 0.7072
# 12:	[0s / 0s],		train_loss: 0.6864
# 13:	[0s / 0s],		train_loss: 0.6735
# 14:	[0s / 0s],		train_loss: 0.6861
# 15:	[0s / 0s],		train_loss: 0.6834
# 16:	[0s / 0s],		train_loss: 0.6807
# 17:	[0s / 0s],		train_loss: 0.6764
# 18:	[0s / 0s],		train_loss: 0.6777
# 19:	[0s / 0s],		train_loss: 0.6833
# 20:	[0s / 0s],		train_loss: 0.6768
# 21:	[0s / 0s],		train_loss: 0.6842
# 22:	[0s / 0s],		train_loss: 0.6743
# 23:	[0s / 0s],		train_loss: 0.6586
# 24:	[0s / 0s],		train_loss: 0.6581
# 25:	[0s / 0s],		train_loss: 0.6631
# 26:	[0s / 0s],		train_loss: 0.6545
# 27:	[0s / 0s],		train_loss: 0.6703
# 28:	[0s / 0s],		train_loss: 0.6600
# 29:	[0s / 0s],		train_loss: 0.6458
# 30:	[0s / 0s],		train_loss: 0.6476
# 31:	[0s / 0s],		train_loss: 0.6421
# 32:	[0s / 0s],		train_loss: 0.6661
# 33:	[0s / 0s],		train_loss: 0.6535
# 34:	[0s / 0s],		train_loss: 0.6368
# 35:	[0s / 0s],		train_loss: 0.6414
# 36:	[0s / 0s],		train_loss: 0.6325
# 37:	[0s / 0s],		train_loss: 0.6309
# 38:	[0s / 0s],		train_loss: 0.6275
# 39:	[0s / 0s],		train_loss: 0.6276
# 40:	[0s / 1s],		train_loss: 0.6452
# 41:	[0s / 1s],		train_loss: 0.6281
# 42:	[0s / 1s],		train_loss: 0.6456
# 43:	[0s / 1s],		train_loss: 0.6054
# 44:	[0s / 1s],		train_loss: 0.6270
# 45:	[0s / 1s],		train_loss: 0.6138
# 46:	[0s / 1s],		train_loss: 0.6134
# 47:	[0s / 1s],		train_loss: 0.6003
# 48:	[0s / 1s],		train_loss: 0.6021
# 49:	[0s / 1s],		train_loss: 0.5941
# 50:	[0s / 1s],		train_loss: 0.6195
# 51:	[0s / 1s],		train_loss: 0.5941
# 52:	[0s / 1s],		train_loss: 0.5729
# 53:	[0s / 1s],		train_loss: 0.6224
# 54:	[0s / 1s],		train_loss: 0.6101
# 55:	[0s / 1s],		train_loss: 0.5587
# 56:	[0s / 1s],		train_loss: 0.5828
# 57:	[0s / 1s],		train_loss: 0.5842
# 58:	[0s / 1s],		train_loss: 0.5782
# 59:	[0s / 1s],		train_loss: 0.5657
# 60:	[0s / 1s],		train_loss: 0.5553
# 61:	[0s / 1s],		train_loss: 0.5731
# 62:	[0s / 1s],		train_loss: 0.5907
# 63:	[0s / 1s],		train_loss: 0.5800
# 64:	[0s / 1s],		train_loss: 0.5454
# 65:	[0s / 1s],		train_loss: 0.5567
# 66:	[0s / 1s],		train_loss: 0.5672
# 67:	[0s / 1s],		train_loss: 0.5450
# 68:	[0s / 1s],		train_loss: 0.5471
# 69:	[0s / 1s],		train_loss: 0.5711
# 70:	[0s / 1s],		train_loss: 0.5376
# 71:	[0s / 1s],		train_loss: 0.5266
# 72:	[0s / 1s],		train_loss: 0.5220
# 73:	[0s / 1s],		train_loss: 0.5341
# 74:	[0s / 1s],		train_loss: 0.5144
# 75:	[0s / 1s],		train_loss: 0.5023
# 76:	[0s / 1s],		train_loss: 0.5092
# 77:	[0s / 1s],		train_loss: 0.5232
# 78:	[0s / 1s],		train_loss: 0.4846
# 79:	[0s / 2s],		train_loss: 0.5605
# 80:	[0s / 2s],		train_loss: 0.5166
# 81:	[0s / 2s],		train_loss: 0.5220
# 82:	[0s / 2s],		train_loss: 0.5425
# 83:	[0s / 2s],		train_loss: 0.5035
# 84:	[0s / 2s],		train_loss: 0.4727
# 85:	[0s / 2s],		train_loss: 0.5135
# 86:	[0s / 2s],		train_loss: 0.4870
# 87:	[0s / 2s],		train_loss: 0.4949
# 88:	[0s / 2s],		train_loss: 0.4585
# 89:	[0s / 2s],		train_loss: 0.4592
# 90:	[0s / 2s],		train_loss: 0.4711
# 91:	[0s / 2s],		train_loss: 0.5142
# 92:	[0s / 2s],		train_loss: 0.4812
# 93:	[0s / 2s],		train_loss: 0.4959
# 94:	[0s / 2s],		train_loss: 0.4538
# 95:	[0s / 2s],		train_loss: 0.4433
# 96:	[0s / 2s],		train_loss: 0.4943
# 97:	[0s / 2s],		train_loss: 0.4806
# 98:	[0s / 2s],		train_loss: 0.4752
# 99:	[0s / 2s],		train_loss: 0.4889
# 0:	[0s / 0s],		train_loss: 0.7362
# 1:	[0s / 0s],		train_loss: 0.7345
# 2:	[0s / 0s],		train_loss: 0.6845
# 3:	[0s / 0s],		train_loss: 0.6981
# 4:	[0s / 0s],		train_loss: 0.6806
# 5:	[0s / 0s],		train_loss: 0.6449
# 6:	[0s / 0s],		train_loss: 0.6415
# 7:	[0s / 0s],		train_loss: 0.6412
# 8:	[0s / 0s],		train_loss: 0.6549
# 9:	[0s / 0s],		train_loss: 0.6571
# 10:	[0s / 0s],		train_loss: 0.6133
# 11:	[0s / 0s],		train_loss: 0.6332
# 12:	[0s / 0s],		train_loss: 0.6101
# 13:	[0s / 0s],		train_loss: 0.5810
# 14:	[0s / 0s],		train_loss: 0.5868
# 15:	[0s / 0s],		train_loss: 0.5960
# 16:	[0s / 0s],		train_loss: 0.6144
# 17:	[0s / 0s],		train_loss: 0.6174
# 18:	[0s / 0s],		train_loss: 0.5762
# 19:	[0s / 0s],		train_loss: 0.5269
# 20:	[0s / 0s],		train_loss: 0.5687
# 21:	[0s / 0s],		train_loss: 0.5557
# 22:	[0s / 0s],		train_loss: 0.5288
# 23:	[0s / 0s],		train_loss: 0.4932
# 24:	[0s / 1s],		train_loss: 0.4995
# 25:	[0s / 1s],		train_loss: 0.5115
# 26:	[0s / 1s],		train_loss: 0.5054
# 27:	[0s / 1s],		train_loss: 0.4613
# 28:	[0s / 1s],		train_loss: 0.4497
# 29:	[0s / 1s],		train_loss: 0.4856
# 30:	[0s / 1s],		train_loss: 0.4702
# 31:	[0s / 1s],		train_loss: 0.5354
# 32:	[0s / 1s],		train_loss: 0.4912
# 33:	[0s / 1s],		train_loss: 0.5591
# 34:	[0s / 1s],		train_loss: 0.4979
# 35:	[0s / 1s],		train_loss: 0.5416
# 36:	[0s / 1s],		train_loss: 0.4941
# 37:	[0s / 1s],		train_loss: 0.5048
# 38:	[0s / 1s],		train_loss: 0.5136
# 39:	[0s / 1s],		train_loss: 0.4702
# 40:	[0s / 1s],		train_loss: 0.4788
# 41:	[0s / 1s],		train_loss: 0.4450
# 42:	[0s / 1s],		train_loss: 0.4338
# 43:	[0s / 1s],		train_loss: 0.4308
# 44:	[0s / 1s],		train_loss: 0.4873
# 45:	[0s / 1s],		train_loss: 0.4435
# 46:	[0s / 1s],		train_loss: 0.4306
# 47:	[0s / 1s],		train_loss: 0.4348
# 48:	[0s / 2s],		train_loss: 0.4451
# 49:	[0s / 2s],		train_loss: 0.3928
# 50:	[0s / 2s],		train_loss: 0.3979
# 51:	[0s / 2s],		train_loss: 0.3667
# 52:	[0s / 2s],		train_loss: 0.3966
# 53:	[0s / 2s],		train_loss: 0.3473
# 54:	[0s / 2s],		train_loss: 0.3711
# 55:	[0s / 2s],		train_loss: 0.3714
# 56:	[0s / 2s],		train_loss: 0.3394
# 57:	[0s / 2s],		train_loss: 0.3517
# 58:	[0s / 2s],		train_loss: 0.3823
# 59:	[0s / 2s],		train_loss: 0.3470
# 60:	[0s / 2s],		train_loss: 0.3322
# 61:	[0s / 2s],		train_loss: 0.3620
# 62:	[0s / 2s],		train_loss: 0.3596
# 63:	[0s / 2s],		train_loss: 0.3907
# 64:	[0s / 2s],		train_loss: 0.4070
# 65:	[0s / 2s],		train_loss: 0.3917
# 66:	[0s / 2s],		train_loss: 0.4373
# 67:	[0s / 2s],		train_loss: 0.4136
# 68:	[0s / 2s],		train_loss: 0.4260
# 69:	[0s / 3s],		train_loss: 0.4352
# 70:	[0s / 3s],		train_loss: 0.4286
# 71:	[0s / 3s],		train_loss: 0.4108
# 72:	[0s / 3s],		train_loss: 0.3685
# 73:	[0s / 3s],		train_loss: 0.3855
# 74:	[0s / 3s],		train_loss: 0.3997
# 75:	[0s / 3s],		train_loss: 0.4419
# 76:	[0s / 3s],		train_loss: 0.3920
# 77:	[0s / 3s],		train_loss: 0.3740
# 78:	[0s / 3s],		train_loss: 0.3678
# 79:	[0s / 3s],		train_loss: 0.3768
# 80:	[0s / 3s],		train_loss: 0.3770
# 81:	[0s / 3s],		train_loss: 0.4204
# 82:	[0s / 3s],		train_loss: 0.3860
# 83:	[0s / 3s],		train_loss: 0.3469
# 84:	[0s / 3s],		train_loss: 0.3301
# 85:	[0s / 3s],		train_loss: 0.3438
# 86:	[0s / 3s],		train_loss: 0.3360
# 87:	[0s / 3s],		train_loss: 0.3739
# 88:	[0s / 3s],		train_loss: 0.3531
# 89:	[0s / 3s],		train_loss: 0.3403
# 90:	[0s / 3s],		train_loss: 0.3304
# 91:	[0s / 4s],		train_loss: 0.3206
# 92:	[0s / 4s],		train_loss: 0.3427
# 93:	[0s / 4s],		train_loss: 0.2934
# 94:	[0s / 4s],		train_loss: 0.3154
# 95:	[0s / 4s],		train_loss: 0.3502
# 96:	[0s / 4s],		train_loss: 0.3147
# 97:	[0s / 4s],		train_loss: 0.3009
# 98:	[0s / 4s],		train_loss: 0.2910
# 99:	[0s / 4s],		train_loss: 0.2572
# 0:	[0s / 0s],		train_loss: 0.7142
# 1:	[0s / 0s],		train_loss: 0.5901
# 2:	[0s / 0s],		train_loss: 0.5478
# 3:	[0s / 0s],		train_loss: 0.5148
# 4:	[0s / 0s],		train_loss: 0.4703
# 5:	[0s / 0s],		train_loss: 0.4528
# 6:	[0s / 0s],		train_loss: 0.4183
# 7:	[0s / 0s],		train_loss: 0.3320
# 8:	[0s / 0s],		train_loss: 0.3756
# 9:	[0s / 0s],		train_loss: 0.3555
# 10:	[0s / 0s],		train_loss: 0.3224
# 11:	[0s / 0s],		train_loss: 0.3166
# 12:	[0s / 0s],		train_loss: 0.3166
# 13:	[0s / 0s],		train_loss: 0.2727
# 14:	[0s / 0s],		train_loss: 0.2441
# 15:	[0s / 1s],		train_loss: 0.2450
# 16:	[0s / 1s],		train_loss: 0.2577
# 17:	[0s / 1s],		train_loss: 0.2254
# 18:	[0s / 1s],		train_loss: 0.2372
# 19:	[0s / 1s],		train_loss: 0.2307
# 20:	[0s / 1s],		train_loss: 0.2312
# 21:	[0s / 1s],		train_loss: 0.2473
# 22:	[0s / 1s],		train_loss: 0.2196
# 23:	[0s / 1s],		train_loss: 0.2015
# 24:	[0s / 1s],		train_loss: 0.2148
# 25:	[0s / 1s],		train_loss: 0.1846
# 26:	[0s / 1s],		train_loss: 0.1887
# 27:	[0s / 1s],		train_loss: 0.1751
# 28:	[0s / 1s],		train_loss: 0.1886
# 29:	[0s / 1s],		train_loss: 0.1599
# 30:	[0s / 2s],		train_loss: 0.1538
# 31:	[0s / 2s],		train_loss: 0.1751
# 32:	[0s / 2s],		train_loss: 0.1760
# 33:	[0s / 2s],		train_loss: 0.1563
# 34:	[0s / 2s],		train_loss: 0.1797
# 35:	[0s / 2s],		train_loss: 0.1575
# 36:	[0s / 2s],		train_loss: 0.1530
# 37:	[0s / 2s],		train_loss: 0.1753
# 38:	[0s / 2s],		train_loss: 0.1583
# 39:	[0s / 2s],		train_loss: 0.1465
# 40:	[0s / 2s],		train_loss: 0.1798
# 41:	[0s / 2s],		train_loss: 0.1704
# 42:	[0s / 2s],		train_loss: 0.1529
# 43:	[0s / 2s],		train_loss: 0.1529
# 44:	[0s / 3s],		train_loss: 0.1485
# 45:	[0s / 3s],		train_loss: 0.1256
# 46:	[0s / 3s],		train_loss: 0.1427
# 47:	[0s / 3s],		train_loss: 0.1272
# 48:	[0s / 3s],		train_loss: 0.1385
# 49:	[0s / 3s],		train_loss: 0.1539
# 50:	[0s / 3s],		train_loss: 0.1189
# 51:	[0s / 3s],		train_loss: 0.1358
# 52:	[0s / 3s],		train_loss: 0.1613
# 53:	[0s / 3s],		train_loss: 0.1379
# 54:	[0s / 3s],		train_loss: 0.1537
# 55:	[0s / 3s],		train_loss: 0.1169
# 56:	[0s / 3s],		train_loss: 0.1361
# 57:	[0s / 3s],		train_loss: 0.1434
# 58:	[0s / 3s],		train_loss: 0.1296
# 59:	[0s / 3s],		train_loss: 0.1502
# 60:	[0s / 4s],		train_loss: 0.1289
# 61:	[0s / 4s],		train_loss: 0.1120
# 62:	[0s / 4s],		train_loss: 0.1385
# 63:	[0s / 4s],		train_loss: 0.1234
# 64:	[0s / 4s],		train_loss: 0.1296
# 65:	[0s / 4s],		train_loss: 0.1156
# 66:	[0s / 4s],		train_loss: 0.1295
# 67:	[0s / 4s],		train_loss: 0.1234
# 68:	[0s / 4s],		train_loss: 0.1258
# 69:	[0s / 4s],		train_loss: 0.1019
# 70:	[0s / 4s],		train_loss: 0.1171
# 71:	[0s / 4s],		train_loss: 0.1419
# 72:	[0s / 4s],		train_loss: 0.1122
# 73:	[0s / 4s],		train_loss: 0.1167
# 74:	[0s / 4s],		train_loss: 0.1147
# 75:	[0s / 5s],		train_loss: 0.1166
# 76:	[0s / 5s],		train_loss: 0.1093
# 77:	[0s / 5s],		train_loss: 0.0848
# 78:	[0s / 5s],		train_loss: 0.1099
# 79:	[0s / 5s],		train_loss: 0.1315
# 80:	[0s / 5s],		train_loss: 0.1233
# 81:	[0s / 5s],		train_loss: 0.1293
# 82:	[0s / 5s],		train_loss: 0.1176
# 83:	[0s / 5s],		train_loss: 0.1371
# 84:	[0s / 5s],		train_loss: 0.1043
# 85:	[0s / 5s],		train_loss: 0.0948
# 86:	[0s / 5s],		train_loss: 0.1006
# 87:	[0s / 5s],		train_loss: 0.1503
# 88:	[0s / 5s],		train_loss: 0.1225
# 89:	[0s / 5s],		train_loss: 0.0947
# 90:	[0s / 5s],		train_loss: 0.1162
# 91:	[0s / 6s],		train_loss: 0.1232
# 92:	[0s / 6s],		train_loss: 0.1005
# 93:	[0s / 6s],		train_loss: 0.1186
# 94:	[0s / 6s],		train_loss: 0.0963
# 95:	[0s / 6s],		train_loss: 0.1092
# 96:	[0s / 6s],		train_loss: 0.1216
# 97:	[0s / 6s],		train_loss: 0.1164
# 98:	[0s / 6s],		train_loss: 0.1279
# 99:	[0s / 6s],		train_loss: 0.0991
# 0:	[0s / 0s],		train_loss: 0.9024
# 1:	[0s / 0s],		train_loss: 0.8607
# 2:	[0s / 0s],		train_loss: 0.7158
# 3:	[0s / 0s],		train_loss: 0.7095
# 4:	[0s / 0s],		train_loss: 0.6838
# 5:	[0s / 0s],		train_loss: 0.6668
# 6:	[0s / 0s],		train_loss: 0.6524
# 7:	[0s / 0s],		train_loss: 0.6655
# 8:	[0s / 0s],		train_loss: 0.6666
# 9:	[0s / 0s],		train_loss: 0.6790
# 10:	[0s / 0s],		train_loss: 0.6845
# 11:	[0s / 0s],		train_loss: 0.6836
# 12:	[0s / 0s],		train_loss: 0.6714
# 13:	[0s / 0s],		train_loss: 0.6606
# 14:	[0s / 0s],		train_loss: 0.6680
# 15:	[0s / 0s],		train_loss: 0.6841
# 16:	[0s / 0s],		train_loss: 0.6597
# 17:	[0s / 0s],		train_loss: 0.6449
# 18:	[0s / 0s],		train_loss: 0.6337
# 19:	[0s / 0s],		train_loss: 0.6408
# 20:	[0s / 0s],		train_loss: 0.6491
# 21:	[0s / 0s],		train_loss: 0.6596
# 22:	[0s / 0s],		train_loss: 0.6643
# 23:	[0s / 0s],		train_loss: 0.6309
# 24:	[0s / 0s],		train_loss: 0.6547
# 25:	[0s / 0s],		train_loss: 0.6180
# 26:	[0s / 0s],		train_loss: 0.6226
# 27:	[0s / 0s],		train_loss: 0.6403
# 28:	[0s / 0s],		train_loss: 0.6146
# 29:	[0s / 0s],		train_loss: 0.6235
# 30:	[0s / 0s],		train_loss: 0.6103
# 31:	[0s / 0s],		train_loss: 0.6249
# 32:	[0s / 0s],		train_loss: 0.6022
# 33:	[0s / 0s],		train_loss: 0.6034
# 34:	[0s / 0s],		train_loss: 0.5999
# 35:	[0s / 0s],		train_loss: 0.6191
# 36:	[0s / 0s],		train_loss: 0.6237
# 37:	[0s / 0s],		train_loss: 0.6021
# 38:	[0s / 0s],		train_loss: 0.5937
# 39:	[0s / 0s],		train_loss: 0.6141
# 40:	[0s / 0s],		train_loss: 0.5840
# 41:	[0s / 0s],		train_loss: 0.5761
# 42:	[0s / 0s],		train_loss: 0.6112
# 43:	[0s / 0s],		train_loss: 0.5913
# 44:	[0s / 0s],		train_loss: 0.5955
# 45:	[0s / 0s],		train_loss: 0.5795
# 46:	[0s / 0s],		train_loss: 0.5604
# 47:	[0s / 0s],		train_loss: 0.5702
# 48:	[0s / 0s],		train_loss: 0.5653
# 49:	[0s / 0s],		train_loss: 0.5875
# 50:	[0s / 0s],		train_loss: 0.5427
# 51:	[0s / 0s],		train_loss: 0.5558
# 52:	[0s / 0s],		train_loss: 0.5632
# 53:	[0s / 0s],		train_loss: 0.5689
# 54:	[0s / 0s],		train_loss: 0.5636
# 55:	[0s / 0s],		train_loss: 0.5377
# 56:	[0s / 0s],		train_loss: 0.5589
# 57:	[0s / 0s],		train_loss: 0.5529
# 58:	[0s / 0s],		train_loss: 0.5660
# 59:	[0s / 0s],		train_loss: 0.5417
# 60:	[0s / 0s],		train_loss: 0.5593
# 61:	[0s / 0s],		train_loss: 0.5644
# 62:	[0s / 0s],		train_loss: 0.5322
# 63:	[0s / 0s],		train_loss: 0.5450
# 64:	[0s / 0s],		train_loss: 0.5671
# 65:	[0s / 0s],		train_loss: 0.5628
# 66:	[0s / 0s],		train_loss: 0.5571
# 67:	[0s / 0s],		train_loss: 0.5551
# 68:	[0s / 1s],		train_loss: 0.5271
# 69:	[0s / 1s],		train_loss: 0.5410
# 70:	[0s / 1s],		train_loss: 0.5523
# 71:	[0s / 1s],		train_loss: 0.5291
# 72:	[0s / 1s],		train_loss: 0.5123
# 73:	[0s / 1s],		train_loss: 0.5190
# 74:	[0s / 1s],		train_loss: 0.5305
# 75:	[0s / 1s],		train_loss: 0.5399
# 76:	[0s / 1s],		train_loss: 0.5113
# 77:	[0s / 1s],		train_loss: 0.4947
# 78:	[0s / 1s],		train_loss: 0.5029
# 79:	[0s / 1s],		train_loss: 0.4735
# 80:	[0s / 1s],		train_loss: 0.5133
# 81:	[0s / 1s],		train_loss: 0.4987
# 82:	[0s / 1s],		train_loss: 0.4967
# 83:	[0s / 1s],		train_loss: 0.4584
# 84:	[0s / 1s],		train_loss: 0.4751
# 85:	[0s / 1s],		train_loss: 0.4539
# 86:	[0s / 1s],		train_loss: 0.4862
# 87:	[0s / 1s],		train_loss: 0.4827
# 88:	[0s / 1s],		train_loss: 0.4958
# 89:	[0s / 1s],		train_loss: 0.4723
# 90:	[0s / 1s],		train_loss: 0.4878
# 91:	[0s / 1s],		train_loss: 0.4435
# 92:	[0s / 1s],		train_loss: 0.4825
# 93:	[0s / 1s],		train_loss: 0.4507
# 94:	[0s / 1s],		train_loss: 0.4763
# 95:	[0s / 1s],		train_loss: 0.4547
# 96:	[0s / 1s],		train_loss: 0.4732
# 97:	[0s / 1s],		train_loss: 0.4571
# 98:	[0s / 1s],		train_loss: 0.4731
# 99:	[0s / 1s],		train_loss: 0.4806
# 0:	[0s / 0s],		train_loss: 0.8462
# 1:	[0s / 0s],		train_loss: 0.8468
# 2:	[0s / 0s],		train_loss: 0.7913
# 3:	[0s / 0s],		train_loss: 0.8153
# 4:	[0s / 0s],		train_loss: 0.7641
# 5:	[0s / 1s],		train_loss: 0.7590
# 6:	[0s / 1s],		train_loss: 0.7669
# 7:	[0s / 1s],		train_loss: 0.7424
# 8:	[0s / 1s],		train_loss: 0.7503
# 9:	[0s / 1s],		train_loss: 0.7256
# 10:	[0s / 2s],		train_loss: 0.7111
# 11:	[0s / 2s],		train_loss: 0.6960
# 12:	[0s / 2s],		train_loss: 0.6825
# 13:	[0s / 2s],		train_loss: 0.6816
# 14:	[0s / 2s],		train_loss: 0.6879
# 15:	[0s / 2s],		train_loss: 0.6789
# 16:	[0s / 3s],		train_loss: 0.6718
# 17:	[0s / 3s],		train_loss: 0.6784
# 18:	[0s / 3s],		train_loss: 0.6622
# 19:	[0s / 3s],		train_loss: 0.6557
# 20:	[0s / 3s],		train_loss: 0.6645
# 21:	[0s / 4s],		train_loss: 0.6624
# 22:	[0s / 4s],		train_loss: 0.6653
# 23:	[0s / 4s],		train_loss: 0.6499
# 24:	[0s / 4s],		train_loss: 0.6627
# 25:	[0s / 4s],		train_loss: 0.6460
# 26:	[0s / 5s],		train_loss: 0.6391
# 27:	[0s / 5s],		train_loss: 0.6308
# 28:	[0s / 5s],		train_loss: 0.6287
# 29:	[0s / 5s],		train_loss: 0.6542
# 30:	[0s / 5s],		train_loss: 0.6396
# 31:	[0s / 5s],		train_loss: 0.6302
# 32:	[0s / 6s],		train_loss: 0.6514
# 33:	[0s / 6s],		train_loss: 0.6252
# 34:	[0s / 6s],		train_loss: 0.6365
# 35:	[0s / 6s],		train_loss: 0.6283
# 36:	[0s / 6s],		train_loss: 0.6163
# 37:	[0s / 7s],		train_loss: 0.6211
# 38:	[0s / 7s],		train_loss: 0.6212
# 39:	[0s / 7s],		train_loss: 0.6222
# 40:	[0s / 7s],		train_loss: 0.6230
# 41:	[0s / 7s],		train_loss: 0.6140
# 42:	[0s / 8s],		train_loss: 0.5979
# 43:	[0s / 8s],		train_loss: 0.6034
# 44:	[0s / 8s],		train_loss: 0.6022
# 45:	[0s / 8s],		train_loss: 0.5985
# 46:	[0s / 8s],		train_loss: 0.6149
# 47:	[0s / 8s],		train_loss: 0.6354
# 48:	[0s / 9s],		train_loss: 0.6026
# 49:	[0s / 9s],		train_loss: 0.6081
# 50:	[0s / 9s],		train_loss: 0.6205
# 51:	[0s / 9s],		train_loss: 0.5928
# 52:	[0s / 9s],		train_loss: 0.6130
# 53:	[0s / 10s],		train_loss: 0.6166
# 54:	[0s / 10s],		train_loss: 0.5957
# 55:	[0s / 10s],		train_loss: 0.6189
# 56:	[0s / 10s],		train_loss: 0.6307
# 57:	[0s / 10s],		train_loss: 0.5996
# 58:	[0s / 11s],		train_loss: 0.6035
# 59:	[0s / 11s],		train_loss: 0.6120
# 60:	[0s / 11s],		train_loss: 0.6055
# 61:	[0s / 11s],		train_loss: 0.6077
# 62:	[0s / 11s],		train_loss: 0.5990
# 63:	[0s / 11s],		train_loss: 0.5930
# 64:	[0s / 12s],		train_loss: 0.5867
# 65:	[0s / 12s],		train_loss: 0.5984
# 66:	[0s / 12s],		train_loss: 0.6066
# 67:	[0s / 12s],		train_loss: 0.5927
# 68:	[0s / 12s],		train_loss: 0.5992
# 69:	[0s / 13s],		train_loss: 0.5999
# 70:	[0s / 13s],		train_loss: 0.5643
# 71:	[0s / 13s],		train_loss: 0.5940
# 72:	[0s / 13s],		train_loss: 0.5708
# 73:	[0s / 13s],		train_loss: 0.6022
# 74:	[0s / 14s],		train_loss: 0.5828
# 75:	[0s / 14s],		train_loss: 0.5869
# 76:	[0s / 14s],		train_loss: 0.5990
# 77:	[0s / 14s],		train_loss: 0.5742
# 78:	[0s / 14s],		train_loss: 0.5584
# 79:	[0s / 15s],		train_loss: 0.5809
# 80:	[0s / 15s],		train_loss: 0.6006
# 81:	[0s / 15s],		train_loss: 0.5826
# 82:	[0s / 15s],		train_loss: 0.5885
# 83:	[0s / 15s],		train_loss: 0.5942
# 84:	[0s / 16s],		train_loss: 0.5781
# 85:	[0s / 16s],		train_loss: 0.5612
# 86:	[0s / 16s],		train_loss: 0.5961
# 87:	[0s / 16s],		train_loss: 0.5728
# 88:	[0s / 16s],		train_loss: 0.5799
# 89:	[0s / 16s],		train_loss: 0.5567
# 90:	[0s / 17s],		train_loss: 0.5498
# 91:	[0s / 17s],		train_loss: 0.5727
# 92:	[0s / 17s],		train_loss: 0.5592
# 93:	[0s / 17s],		train_loss: 0.5784
# 94:	[0s / 17s],		train_loss: 0.5714
# 95:	[0s / 18s],		train_loss: 0.5578
# 96:	[0s / 18s],		train_loss: 0.5956
# 97:	[0s / 18s],		train_loss: 0.5528
# 98:	[0s / 18s],		train_loss: 0.5634
# 99:	[0s / 18s],		train_loss: 0.5659

# %% [markdown]
# # III. Results

# %% [markdown]
# We output the AUC value at 5 and 10 years and Uno's C-index at 5 and 10 years, with standard deviation among the 5 folds.

# %%
mean_all = results_all.mean(axis=0)
std_all = results_all.std(axis=0, ddof=0)
measures = pd.concat([mean_all.rename('mean'), std_all.rename('std')],axis = 1)
measures
# Out:
#             mean       std
# unoc5   0.664347  0.026802
# unoc10  0.633312  0.026915
# ibs     0.210310  0.043608
